# %% [markdown]
# # Tree Graph Algorithm: From tskit Tables to Renderable Coordinates
#
# This notebook explains the complete pipeline for converting a tskit tree sequence into a renderable graph structure. The algorithm takes edges and nodes tables plus a tree index and produces x,y coordinates suitable for visualization.
#
# ## Overview
#
# The pipeline consists of these key steps:
#
# 1. **Load tree sequence** - Read the `.trees` file using tskit
# 2. **Edge filtering** - Find edges active at a specific genomic position
# 3. **Build parent array** - Map each node to its parent
# 4. **Build CSR children structure** - Compressed Sparse Row format for efficient traversal
# 5. **Compute Y coordinate** - Normalize node times to [0,1]
# 6. **Compute X coordinate** - Post-order traversal for layout positioning
# 7. **Serialize to PyArrow** - Binary format for network transfer

# %% [markdown]
# ## Cell 1: Dependencies & Setup

# %%
import numpy as np
import tskit
import tszip
import pyarrow as pa
from numba import njit
from dataclasses import dataclass
from typing import Optional
import matplotlib.pyplot as plt

# Set display options for better array printing
np.set_printoptions(threshold=20, edgeitems=5)

# %% [markdown]
# ## Cell 2: Load Tree Sequence
#
# A tree sequence is a compact representation of genetic ancestry. It stores:
# - **Nodes**: Individual ancestors or samples with associated times
# - **Edges**: Parent-child relationships that span genomic intervals
# - **Trees**: The set of edges active at each genomic position forms a tree
#
# Modify the path below to point to your `.trees` or `.tsz` file:

# %%
# Modify this path to your tree sequence file
TREE_FILE = "../../../UPLOADS/test/slimquant2.trees"

# Load the tree sequence
# ts = tskit.load(TREE_FILE)

TREE_FILE = "/storage2/pratik/git/llm-viz/temp/compete_refactor/packages/backend/UPLOADS/Uploads/1kg_chr22.trees.tsz"
# Load the tree sequence
# ts = tskit.load(TREE_FILE)
ts = tszip.load(TREE_FILE)

# Print basic statistics
print(f"Tree Sequence Statistics:")
print(f"  Number of trees: {ts.num_trees:,}")
print(f"  Number of nodes: {ts.num_nodes:,}")
print(f"  Number of edges: {ts.num_edges:,}")
print(f"  Number of samples: {ts.num_samples:,}")
print(f"  Sequence length: {ts.sequence_length:,.0f} bp")
print(f"  Time range: [{ts.min_time:.2f}, {ts.max_time:.2f}]")
print(f"")
print(f"Breakpoints (first 10):")
breakpoints = list(ts.breakpoints())
print(f"  {breakpoints[:10]}")
if len(breakpoints) > 10:
    print(f"  ... and {len(breakpoints) - 10} more")
# Out:
# Tree Sequence Statistics:
#   Number of trees: 322,938
#   Number of nodes: 433,995
#   Number of edges: 4,842,595
#   Number of samples: 5,008
#   Sequence length: 51,304,568 bp
#   Time range: [0.00, 5003.00]
#
# Breakpoints (first 10):
#   [0.0, 16103536.0, 16103787.0, 16103804.0, 16103894.0, 16103914.0, 16105128.0, 16106069.0, 16108260.0, 16108650.0]
#   ... and 322929 more

# %% [markdown]
# ## Cell 3: Explore the Tables (Edges & Nodes)
#
# The tskit tables contain the raw data we need:
#
# ### Edges Table
# Each edge represents a parent-child relationship over a genomic interval:
# - `left`: Start of the genomic interval (inclusive)
# - `right`: End of the genomic interval (exclusive)
# - `parent`: Parent node ID
# - `child`: Child node ID
#
# ### Nodes Table
# Each node represents an ancestor or sample:
# - `time`: When this node existed (0 = present, larger = older)
# - `flags`: Bit flags (1 = sample node)

# %%
edges = ts.tables.edges
nodes = ts.tables.nodes

print("=== EDGES TABLE ===")
print(f"Total edges: {len(edges)}")
print(f"")
print(f"First 10 edges:")
print(f"{'left':>12} {'right':>12} {'parent':>8} {'child':>8}")
print("-" * 44)
for i in range(min(10, len(edges))):
    print(f"{edges.left[i]:>12.1f} {edges.right[i]:>12.1f} {edges.parent[i]:>8} {edges.child[i]:>8}")

print(f"")
print("=== NODES TABLE ===")
print(f"Total nodes: {len(nodes)}")
print(f"")
print(f"First 10 nodes:")
print(f"{'node_id':>8} {'time':>12} {'flags':>6} {'is_sample':>10}")
print("-" * 40)
for i in range(min(10, len(nodes))):
    is_sample = "Yes" if nodes.flags[i] & 1 else "No"
    print(f"{i:>8} {nodes.time[i]:>12.4f} {nodes.flags[i]:>6} {is_sample:>10}")
# Out:
# === EDGES TABLE ===
# Total edges: 4842595
#
# First 10 edges:
#         left        right   parent    child
# --------------------------------------------
#   22496485.0   22505588.0     5008        0
#   22496485.0   22505588.0     5008        1
#   31978377.0   32049334.0     5009        0
#   31978377.0   32049334.0     5009        1
#   44418560.0   44620593.0     5010        5
#   44418560.0   44620593.0     5010       24
#   27645152.0   27773711.0     5011       27
#   27645152.0   27773711.0     5011       32
#   23852646.0   23940052.0     5012       26
#   23852646.0   23940052.0     5012       41
#
# === NODES TABLE ===
# Total nodes: 433995
#
# First 10 nodes:
#  node_id         time  flags  is_sample
# ----------------------------------------
#        0       0.0000      1        Yes
#        1       0.0000      1        Yes
#        2       0.0000      1        Yes
#        3       0.0000      1        Yes
#        4       0.0000      1        Yes
#        5       0.0000      1        Yes
#        6       0.0000      1        Yes
#        7       0.0000      1        Yes
#        8       0.0000      1        Yes
#        9       0.0000      1        Yes

# %% [markdown]
# ## Cell 4: Edge Filtering for a Single Tree
#
# **Key algorithm step**: For a tree at index `idx`, we need to find which edges are "active" at that tree's genomic position.
#
# An edge is active if its interval contains the tree's left breakpoint:
# ```
# edge.left <= breakpoint[idx] < edge.right
# ```
#
# This is because trees are defined by the edges that span each genomic interval. The `breakpoints` array gives us the boundaries between trees.

# %%
# Choose which tree to visualize
tree_idx = 0

# Get the left boundary of this tree's interval
interval_left = breakpoints[tree_idx]
interval_right = breakpoints[tree_idx + 1]

print(f"Tree {tree_idx} spans genomic interval: [{interval_left:.1f}, {interval_right:.1f})")
print(f"")

# Filter edges: find edges where left <= interval_left < right
active_mask = (edges.left <= interval_left) & (edges.right > interval_left)
active_parents = edges.parent[active_mask]
active_children = edges.child[active_mask]

print(f"Active edges for tree {tree_idx}: {np.sum(active_mask)} (out of {len(edges)} total)")
print(f"")
print(f"First 10 active edges:")
print(f"{'parent':>8} {'child':>8}")
print("-" * 18)
for i in range(min(10, len(active_parents))):
    print(f"{active_parents[i]:>8} {active_children[i]:>8}")

print(f"")
print(f"Unique nodes in tree: {len(set(active_parents) | set(active_children))}")
# Out:
# Tree 0 spans genomic interval: [0.0, 16103536.0)
#
# Active edges for tree 0: 5336 (out of 4842595 total)
#
# First 10 active edges:
#   parent    child
# ------------------
#     5584     1161
#     5584     1559
#     5584     2138
#     5763      981
#     5763     1906
#     6208       48
#     6208     2716
#     6257     2760
#     6257     2860
#     6686      429
#
# Unique nodes in tree: 5337

# %% [markdown]
# ## Cell 5: Build Parent Array
#
# The parent array provides O(1) lookup: `parent[child_id] = parent_id`
#
# - A value of `-1` means "no parent" (i.e., this node is a root or not in the tree)
# - We initialize all values to `-1` and then fill in from active edges

# %%
num_nodes = len(nodes.time)

# Initialize parent array: -1 means "no parent"
parent = np.full(num_nodes, -1, dtype=np.int32)

# Fill in parent relationships from active edges
# parent[child] = parent_node
parent[active_children] = active_parents

print(f"Parent array shape: {parent.shape}")
print(f"")

# Track which nodes are in this tree
in_tree = np.zeros(num_nodes, dtype=np.bool_)
in_tree[active_children] = True
in_tree[active_parents] = True

# Find roots: nodes in the tree with no parent
roots = np.where(in_tree & (parent == -1))[0]

print(f"Nodes in tree: {np.sum(in_tree)}")
print(f"Root nodes: {roots}")
print(f"")

# Show parent array for first 10 in-tree nodes
in_tree_indices = np.where(in_tree)[0][:10]
print(f"Sample parent lookups (first 10 in-tree nodes):")
print(f"{'node_id':>8} {'parent':>8}")
print("-" * 18)
for node_id in in_tree_indices:
    print(f"{node_id:>8} {parent[node_id]:>8}")
# Out:
# Parent array shape: (433995,)
#
# Nodes in tree: 5337
# Root nodes: [433994]
#
# Sample parent lookups (first 10 in-tree nodes):
#  node_id   parent
# ------------------
#        0   141729
#        1   388119
#        2   345410
#        3   388119
#        4    95588
#        5   245795
#        6   174144
#        7   419561
#        8   180379
#        9   339206

# %% [markdown]
# ## Cell 6: Build CSR Children Structure
#
# **Compressed Sparse Row (CSR)** format is an efficient way to store the children of each node.
#
# CSR uses two arrays:
# - `children_indptr`: Row pointers (length = num_nodes + 1)
# - `children_data`: Flattened array of all children
#
# To get children of node `n`:
# ```python
# children = children_data[children_indptr[n]:children_indptr[n+1]]
# ```
#
# This gives O(1) access to any node's children without Python lists.

# %%
# Step 1: Count children for each parent
child_counts = np.bincount(active_parents, minlength=num_nodes).astype(np.int32)

# Step 2: Build indptr as cumulative sum of counts
children_indptr = np.zeros(num_nodes + 1, dtype=np.int32)
children_indptr[1:] = np.cumsum(child_counts)

# Step 3: Sort children by parent to create contiguous blocks
sort_idx = np.argsort(active_parents, kind='stable')
children_data = active_children[sort_idx].astype(np.int32)

print(f"CSR Structure:")
print(f"  children_indptr shape: {children_indptr.shape}")
print(f"  children_data shape: {children_data.shape}")
print(f"")

# Helper function to get children
def get_children(node_id):
    return children_data[children_indptr[node_id]:children_indptr[node_id + 1]]

def is_tip(node_id):
    return children_indptr[node_id + 1] == children_indptr[node_id]

# Demonstrate CSR lookups
print("CSR Lookups (nodes with children):")
print(f"{'node_id':>8} {'num_children':>12} {'children':>20}")
print("-" * 44)
shown = 0
for node_id in in_tree_indices:
    children = get_children(node_id)
    if len(children) > 0:
        print(f"{node_id:>8} {len(children):>12} {str(list(children)):>20}")
        shown += 1
        if shown >= 5:
            break

# Count tips
num_tips = sum(1 for n in np.where(in_tree)[0] if is_tip(n))
print(f"")
print(f"Total tips (leaf nodes): {num_tips}")
# Out:
# CSR Structure:
#   children_indptr shape: (433996,)
#   children_data shape: (5336,)
#
# CSR Lookups (nodes with children):
#  node_id num_children             children
# --------------------------------------------
#
# Total tips (leaf nodes): 5008

# %% [markdown]
# ## Cell 7: Compute Y Coordinate (Normalized Time)
#
# The Y coordinate maps node times to the [0, 1] range.
#
# We invert the time so that:
# - Root (oldest, max_time) -> y = 0 (top/left of tree)
# - Tips (youngest, min_time) -> y = 1 (bottom/right of tree)
#
# Formula:
# ```python
# y = (max_time - node_time) / (max_time - min_time)
# ```

# %%
node_times = nodes.time
min_time = ts.min_time
max_time = ts.max_time

print(f"Time range: [{min_time:.4f}, {max_time:.4f}]")
print(f"")

# Compute normalized Y coordinate (vectorized)
time_range = max_time - min_time if max_time > min_time else 1.0
y = ((max_time - node_times) / time_range).astype(np.float32)

print(f"Y coordinates (time-based):")
print(f"{'node_id':>8} {'time':>12} {'y':>8}")
print("-" * 32)

# Show roots and tips
for node_id in roots:
    print(f"{node_id:>8} {node_times[node_id]:>12.4f} {y[node_id]:>8.4f}  <- ROOT")

print("...")

# Show some tips
tips = [n for n in np.where(in_tree)[0] if is_tip(n)][:3]
for node_id in tips:
    print(f"{node_id:>8} {node_times[node_id]:>12.4f} {y[node_id]:>8.4f}  <- TIP")
# Out:
# Time range: [0.0000, 5003.0000]
#
# Y coordinates (time-based):
#  node_id         time        y
# --------------------------------
#   433994    5003.0000   0.0000  <- ROOT
# ...
#        0       0.0000   1.0000  <- TIP
#        1       0.0000   1.0000  <- TIP
#        2       0.0000   1.0000  <- TIP

# %% [markdown]
# ## Cell 8: Compute X Coordinate (Post-Order Traversal) - CORE ALGORITHM
#
# The X coordinate determines the horizontal position of each node. We use **post-order traversal**:
#
# 1. Visit all children first (post-order)
# 2. Tips get sequential x values: 0, 1, 2, ...
# 3. Internal nodes get the midpoint of their children's x range: `(min + max) / 2`
# 4. Normalize to [0, 1] by dividing by (tip_count - 1)
#
# This creates a layout where:
# - Tips are evenly spaced
# - Parents are centered between their leftmost and rightmost descendants
#
# **Note**: This matches the jstree.js algorithm which uses `(first_child + last_child) / 2`. Since children are processed in order, this is equivalent to `(min + max) / 2`.
#
# ### Why Stack-Based?
# We use an iterative stack-based approach instead of recursion to:
# - Avoid Python's recursion limit (default ~1000)
# - Enable Numba JIT compilation for speed
# - Handle very deep trees efficiently

# %%
# Pure Python version (slower but easier to understand)
def compute_x_python(children_indptr, children_data, roots, num_nodes, verbose=False):
    """
    Pure Python post-order traversal for computing x coordinates.
    Includes optional verbose output to trace the algorithm.
    
    Internal nodes use (min + max) / 2 of children's x values to match jstree.js.
    Children are pushed in reverse order so they're processed left-to-right (matching Newick).
    """
    x = np.full(num_nodes, -1.0, dtype=np.float32)
    tip_counter = 0
    
    # Stack entries: (node, visited)
    # visited=False: first visit, push children
    # visited=True: children processed, compute x
    
    for root in roots:
        stack = [(root, False)]
        
        while stack:
            node, visited = stack.pop()
            
            # Get children using CSR lookup
            start = children_indptr[node]
            end = children_indptr[node + 1]
            children = children_data[start:end]
            
            if not visited and len(children) > 0:
                # First visit: push self as visited, then push children in REVERSE order
                # (so they get popped/processed in forward order, matching Newick)
                stack.append((node, True))
                for child in reversed(children):
                    stack.append((child, False))
                if verbose:
                    print(f"  Node {node}: pushed children {list(reversed(children))} (reversed)")
            else:
                # Post-order processing
                if len(children) == 0:
                    # Tip: assign sequential x value
                    x[node] = tip_counter
                    if verbose:
                        print(f"  Node {node}: TIP -> x = {tip_counter}")
                    tip_counter += 1
                else:
                    # Internal: (min + max) / 2 of children's x values (matches jstree.js)
                    children_x = [x[c] for c in children]
                    x[node] = (min(children_x) + max(children_x)) / 2.0
                    if verbose:
                        print(f"  Node {node}: INTERNAL, children_x={children_x}, min={min(children_x):.2f}, max={max(children_x):.2f} -> x = {x[node]:.2f}")
    
    return x, tip_counter

# Run with verbose output on a small example
print("=== Post-Order Traversal Trace ===")
print(f"Starting from roots: {roots}")
print(f"")

x_python, tip_count = compute_x_python(
    children_indptr, children_data, roots.astype(np.int32), num_nodes, 
    verbose=True
)

print(f"")
print(f"Tip count: {tip_count}")
# Out:
# === Post-Order Traversal Trace ===
# Starting from roots: [433994]
#
#   Node 433994: pushed children [np.int32(432940), np.int32(307324), np.int32(306915), np.int32(275534), np.int32(244360), np.int32(239956), np.int32(215529), np.int32(199292), np.int32(192748), np.int32(180379), np.int32(151820), np.int32(146990), np.int32(140174), np.int32(139959), np.int32(137801), np.int32(124828), np.int32(115787), np.int32(114742), np.int32(109720), np.int32(108561), np.int32(95588), np.int32(83028), np.int32(17509), np.int32(4963), np.int32(4949), np.int32(4917), np.int32(4859), np.int32(4844), np.int32(4833), np.int32(4831), np.int32(4821), np.int32(4802), np.int32(4766), np.int32(4750), np.int32(4631), np.int32(4585), np.int32(4545), np.int32(4534), np.int32(4518), np.int32(4491), np.int32(4409), np.int32(4405), np.int32(4335), np.int32(4299), np.int32(4260), np.int32(4252), np.int32(4251), np.int32(4227), np.int32(4153), np.int32(4145), np.int32(4130), np.int32(4115), np.int32(4114), np.int32(4068), np.int32(4053), np.int32(4050), np.int32(4047), np.int32(4008), np.int32(3917), np.int32(3887), np.int32(3885), np.int32(3879), np.int32(3875), np.int32(3866), np.int32(3836), np.int32(3785), np.int32(3763), np.int32(3759), np.int32(3746), np.int32(3722), np.int32(3710), np.int32(3695), np.int32(3690), np.int32(3679), np.int32(3667), np.int32(3582), np.int32(3581), np.int32(3554), np.int32(3535), np.int32(3524), np.int32(3495), np.int32(3473), np.int32(3402), np.int32(3365), np.int32(3328), np.int32(3218), np.int32(3214), np.int32(3180), np.int32(3140), np.int32(3117), np.int32(3114), np.int32(3052), np.int32(3051), np.int32(3017), np.int32(2979), np.int32(2957), np.int32(2954), np.int32(2948), np.int32(2940), np.int32(2890), np.int32(2857), np.int32(2853), np.int32(2816), np.int32(2811), np.int32(2806), np.int32(2803), np.int32(2757), np.int32(2744), np.int32(2692), np.int32(2669), np.int32(2667), np.int32(2644), np.int32(2640), np.int32(2638), np.int32(2634), np.int32(2626), np.int32(2623), np.int32(2602), np.int32(2561), np.int32(2554), np.int32(2533), np.int32(2530), np.int32(2513), np.int32(2474), np.int32(2462), np.int32(2461), np.int32(2451), np.int32(2439), np.int32(2434), np.int32(2427), np.int32(2405), np.int32(2382), np.int32(2352), np.int32(2340), np.int32(2326), np.int32(2315), np.int32(2289), np.int32(2286), np.int32(2275), np.int32(2263), np.int32(2260), np.int32(2219), np.int32(2216), np.int32(2215), np.int32(2193), np.int32(2191), np.int32(2131), np.int32(2128), np.int32(2108), np.int32(2104), np.int32(2078), np.int32(2059), np.int32(2040), np.int32(2023), np.int32(2016), np.int32(2014), np.int32(1990), np.int32(1984), np.int32(1976), np.int32(1968), np.int32(1965), np.int32(1933), np.int32(1898), np.int32(1887), np.int32(1878), np.int32(1860), np.int32(1823), np.int32(1813), np.int32(1811), np.int32(1806), np.int32(1788), np.int32(1716), np.int32(1657), np.int32(1646), np.int32(1632), np.int32(1612), np.int32(1594), np.int32(1504), np.int32(1496), np.int32(1477), np.int32(1450), np.int32(1438), np.int32(1398), np.int32(1351), np.int32(1319), np.int32(1311), np.int32(1303), np.int32(1278), np.int32(1265), np.int32(1253), np.int32(1241), np.int32(1180), np.int32(1097), np.int32(1080), np.int32(1077), np.int32(1031), np.int32(948), np.int32(938), np.int32(904), np.int32(903), np.int32(897), np.int32(840), np.int32(822), np.int32(808), np.int32(790), np.int32(762), np.int32(693), np.int32(692), np.int32(682), np.int32(673), np.int32(664), np.int32(612), np.int32(552), np.int32(538), np.int32(533), np.int32(481), np.int32(434), np.int32(402), np.int32(382), np.int32(299), np.int32(294), np.int32(207), np.int32(142), np.int32(109), np.int32(84), np.int32(76), np.int32(70)] (reversed)
#   Node 70: TIP -> x = 0
#   Node 76: TIP -> x = 1
#   Node 84: TIP -> x = 2
#   Node 109: TIP -> x = 3
#   Node 142: TIP -> x = 4
#   Node 207: TIP -> x = 5
#   Node 294: TIP -> x = 6
#   Node 299: TIP -> x = 7
#   Node 382: TIP -> x = 8
#   Node 402: TIP -> x = 9
#   Node 434: TIP -> x = 10
#   Node 481: TIP -> x = 11
#   Node 533: TIP -> x = 12
#   Node 538: TIP -> x = 13
#   Node 552: TIP -> x = 14
#   Node 612: TIP -> x = 15
#   Node 664: TIP -> x = 16
#   Node 673: TIP -> x = 17
#   Node 682: TIP -> x = 18
#   Node 692: TIP -> x = 19
#   Node 693: TIP -> x = 20
#   Node 762: TIP -> x = 21
#   Node 790: TIP -> x = 22
#   Node 808: TIP -> x = 23
#   Node 822: TIP -> x = 24
#   Node 840: TIP -> x = 25
#   Node 897: TIP -> x = 26
#   Node 903: TIP -> x = 27
#   Node 904: TIP -> x = 28
#   Node 938: TIP -> x = 29
#   Node 948: TIP -> x = 30
#   Node 1031: TIP -> x = 31
#   Node 1077: TIP -> x = 32
#   Node 1080: TIP -> x = 33
#   Node 1097: TIP -> x = 34
#   Node 1180: TIP -> x = 35
#   Node 1241: TIP -> x = 36
#   Node 1253: TIP -> x = 37
#   Node 1265: TIP -> x = 38
#   Node 1278: TIP -> x = 39
#   Node 1303: TIP -> x = 40
#   Node 1311: TIP -> x = 41
#   Node 1319: TIP -> x = 42
#   Node 1351: TIP -> x = 43
#   Node 1398: TIP -> x = 44
#   Node 1438: TIP -> x = 45
#   Node 1450: TIP -> x = 46
#   Node 1477: TIP -> x = 47
#   Node 1496: TIP -> x = 48
#   Node 1504: TIP -> x = 49
#   Node 1594: TIP -> x = 50
#   Node 1612: TIP -> x = 51
#   Node 1632: TIP -> x = 52
#   Node 1646: TIP -> x = 53
#   Node 1657: TIP -> x = 54
#   Node 1716: TIP -> x = 55
#   Node 1788: TIP -> x = 56
#   Node 1806: TIP -> x = 57
#   Node 1811: TIP -> x = 58
#   Node 1813: TIP -> x = 59
#   Node 1823: TIP -> x = 60
#   Node 1860: TIP -> x = 61
#   Node 1878: TIP -> x = 62
#   Node 1887: TIP -> x = 63
#   Node 1898: TIP -> x = 64
#   Node 1933: TIP -> x = 65
#   Node 1965: TIP -> x = 66
#   Node 1968: TIP -> x = 67
#   Node 1976: TIP -> x = 68
#   Node 1984: TIP -> x = 69
#   Node 1990: TIP -> x = 70
#   Node 2014: TIP -> x = 71
#   Node 2016: TIP -> x = 72
#   Node 2023: TIP -> x = 73
#   Node 2040: TIP -> x = 74
#   Node 2059: TIP -> x = 75
#   Node 2078: TIP -> x = 76
#   Node 2104: TIP -> x = 77
#   Node 2108: TIP -> x = 78
#   Node 2128: TIP -> x = 79
#   Node 2131: TIP -> x = 80
#   Node 2191: TIP -> x = 81
#   Node 2193: TIP -> x = 82
#   Node 2215: TIP -> x = 83
#   Node 2216: TIP -> x = 84
#   Node 2219: TIP -> x = 85
#   Node 2260: TIP -> x = 86
#   Node 2263: TIP -> x = 87
#   Node 2275: TIP -> x = 88
#   Node 2286: TIP -> x = 89
#   Node 2289: TIP -> x = 90
#   Node 2315: TIP -> x = 91
#   Node 2326: TIP -> x = 92
#   Node 2340: TIP -> x = 93
#   Node 2352: TIP -> x = 94
#   Node 2382: TIP -> x = 95
#   Node 2405: TIP -> x = 96
#   Node 2427: TIP -> x = 97
#   Node 2434: TIP -> x = 98
#   Node 2439: TIP -> x = 99
#   Node 2451: TIP -> x = 100
#   Node 2461: TIP -> x = 101
#   Node 2462: TIP -> x = 102
#   Node 2474: TIP -> x = 103
#   Node 2513: TIP -> x = 104
#   Node 2530: TIP -> x = 105
#   Node 2533: TIP -> x = 106
#   Node 2554: TIP -> x = 107
#   Node 2561: TIP -> x = 108
#   Node 2602: TIP -> x = 109
#   Node 2623: TIP -> x = 110
#   Node 2626: TIP -> x = 111
#   Node 2634: TIP -> x = 112
#   Node 2638: TIP -> x = 113
#   Node 2640: TIP -> x = 114
#   Node 2644: TIP -> x = 115
#   Node 2667: TIP -> x = 116
#   Node 2669: TIP -> x = 117
#   Node 2692: TIP -> x = 118
#   Node 2744: TIP -> x = 119
#   Node 2757: TIP -> x = 120
#   Node 2803: TIP -> x = 121
#   Node 2806: TIP -> x = 122
#   Node 2811: TIP -> x = 123
#   Node 2816: TIP -> x = 124
#   Node 2853: TIP -> x = 125
#   Node 2857: TIP -> x = 126
#   Node 2890: TIP -> x = 127
#   Node 2940: TIP -> x = 128
#   Node 2948: TIP -> x = 129
#   Node 2954: TIP -> x = 130
#   Node 2957: TIP -> x = 131
#   Node 2979: TIP -> x = 132
#   Node 3017: TIP -> x = 133
#   Node 3051: TIP -> x = 134
#   Node 3052: TIP -> x = 135
#   Node 3114: TIP -> x = 136
#   Node 3117: TIP -> x = 137
#   Node 3140: TIP -> x = 138
#   Node 3180: TIP -> x = 139
#   Node 3214: TIP -> x = 140
#   Node 3218: TIP -> x = 141
#   Node 3328: TIP -> x = 142
#   Node 3365: TIP -> x = 143
#   Node 3402: TIP -> x = 144
#   Node 3473: TIP -> x = 145
#   Node 3495: TIP -> x = 146
#   Node 3524: TIP -> x = 147
#   Node 3535: TIP -> x = 148
#   Node 3554: TIP -> x = 149
#   Node 3581: TIP -> x = 150
#   Node 3582: TIP -> x = 151
#   Node 3667: TIP -> x = 152
#   Node 3679: TIP -> x = 153
#   Node 3690: TIP -> x = 154
#   Node 3695: TIP -> x = 155
#   Node 3710: TIP -> x = 156
#   Node 3722: TIP -> x = 157
#   Node 3746: TIP -> x = 158
#   Node 3759: TIP -> x = 159
#   Node 3763: TIP -> x = 160
#   Node 3785: TIP -> x = 161
#   Node 3836: TIP -> x = 162
#   Node 3866: TIP -> x = 163
#   Node 3875: TIP -> x = 164
#   Node 3879: TIP -> x = 165
#   Node 3885: TIP -> x = 166
#   Node 3887: TIP -> x = 167
#   Node 3917: TIP -> x = 168
#   Node 4008: TIP -> x = 169
#   Node 4047: TIP -> x = 170
#   Node 4050: TIP -> x = 171
#   Node 4053: TIP -> x = 172
#   Node 4068: TIP -> x = 173
#   Node 4114: TIP -> x = 174
#   Node 4115: TIP -> x = 175
#   Node 4130: TIP -> x = 176
#   Node 4145: TIP -> x = 177
#   Node 4153: TIP -> x = 178
#   Node 4227: TIP -> x = 179
#   Node 4251: TIP -> x = 180
#   Node 4252: TIP -> x = 181
#   Node 4260: TIP -> x = 182
#   Node 4299: TIP -> x = 183
#   Node 4335: TIP -> x = 184
#   Node 4405: TIP -> x = 185
#   Node 4409: TIP -> x = 186
#   Node 4491: TIP -> x = 187
#   Node 4518: TIP -> x = 188
#   Node 4534: TIP -> x = 189
#   Node 4545: TIP -> x = 190
#   Node 4585: TIP -> x = 191
#   Node 4631: TIP -> x = 192
#   Node 4750: TIP -> x = 193
#   Node 4766: TIP -> x = 194
#   Node 4802: TIP -> x = 195
#   Node 4821: TIP -> x = 196
#   Node 4831: TIP -> x = 197
#   Node 4833: TIP -> x = 198
#   Node 4844: TIP -> x = 199
#   Node 4859: TIP -> x = 200
#   Node 4917: TIP -> x = 201
#   Node 4949: TIP -> x = 202
#   Node 4963: TIP -> x = 203
#   Node 17509: pushed children [np.int32(4307), np.int32(4304), np.int32(4241), np.int32(4199), np.int32(4124), np.int32(3716), np.int32(3705), np.int32(3593), np.int32(2814), np.int32(2124), np.int32(2114), np.int32(1942), np.int32(1893), np.int32(1494)] (reversed)
#   Node 1494: TIP -> x = 204
#   Node 1893: TIP -> x = 205
#   Node 1942: TIP -> x = 206
#   Node 2114: TIP -> x = 207
#   Node 2124: TIP -> x = 208
#   Node 2814: TIP -> x = 209
#   Node 3593: TIP -> x = 210
#   Node 3705: TIP -> x = 211
#   Node 3716: TIP -> x = 212
#   Node 4124: TIP -> x = 213
#   Node 4199: TIP -> x = 214
#   Node 4241: TIP -> x = 215
#   Node 4304: TIP -> x = 216
#   Node 4307: TIP -> x = 217
#   Node 17509: INTERNAL, children_x=[np.float32(204.0), np.float32(205.0), np.float32(206.0), np.float32(207.0), np.float32(208.0), np.float32(209.0), np.float32(210.0), np.float32(211.0), np.float32(212.0), np.float32(213.0), np.float32(214.0), np.float32(215.0), np.float32(216.0), np.float32(217.0)], min=204.00, max=217.00 -> x = 210.50
#   Node 83028: pushed children [np.int32(4459), np.int32(3769), np.int32(214)] (reversed)
#   Node 214: TIP -> x = 218
#   Node 3769: TIP -> x = 219
#   Node 4459: TIP -> x = 220
#   Node 83028: INTERNAL, children_x=[np.float32(218.0), np.float32(219.0), np.float32(220.0)], min=218.00, max=220.00 -> x = 219.00
#   Node 95588: pushed children [np.int32(93759), np.int32(93065), np.int32(9170), np.int32(4740), np.int32(4735), np.int32(4679), np.int32(4636), np.int32(4579), np.int32(4564), np.int32(4525), np.int32(4476), np.int32(4324), np.int32(4245), np.int32(4210), np.int32(4147), np.int32(4069), np.int32(3969), np.int32(3923), np.int32(3804), np.int32(3736), np.int32(3514), np.int32(3510), np.int32(3443), np.int32(3439), np.int32(3345), np.int32(3129), np.int32(3057), np.int32(2846), np.int32(2813), np.int32(2808), np.int32(2682), np.int32(2490), np.int32(2456), np.int32(2431), np.int32(2346), np.int32(2264), np.int32(2209), np.int32(2186), np.int32(1953), np.int32(1946), np.int32(1620), np.int32(1162), np.int32(1132), np.int32(1042), np.int32(732), np.int32(657), np.int32(337), np.int32(317), np.int32(236), np.int32(81), np.int32(45), np.int32(4)] (reversed)
#   Node 4: TIP -> x = 221
#   Node 45: TIP -> x = 222
#   Node 81: TIP -> x = 223
#   Node 236: TIP -> x = 224
#   Node 317: TIP -> x = 225
#   Node 337: TIP -> x = 226
#   Node 657: TIP -> x = 227
#   Node 732: TIP -> x = 228
#   Node 1042: TIP -> x = 229
#   Node 1132: TIP -> x = 230
#   Node 1162: TIP -> x = 231
#   Node 1620: TIP -> x = 232
#   Node 1946: TIP -> x = 233
#   Node 1953: TIP -> x = 234
#   Node 2186: TIP -> x = 235
#   Node 2209: TIP -> x = 236
#   Node 2264: TIP -> x = 237
#   Node 2346: TIP -> x = 238
#   Node 2431: TIP -> x = 239
#   Node 2456: TIP -> x = 240
#   Node 2490: TIP -> x = 241
#   Node 2682: TIP -> x = 242
#   Node 2808: TIP -> x = 243
#   Node 2813: TIP -> x = 244
#   Node 2846: TIP -> x = 245
#   Node 3057: TIP -> x = 246
#   Node 3129: TIP -> x = 247
#   Node 3345: TIP -> x = 248
#   Node 3439: TIP -> x = 249
#   Node 3443: TIP -> x = 250
#   Node 3510: TIP -> x = 251
#   Node 3514: TIP -> x = 252
#   Node 3736: TIP -> x = 253
#   Node 3804: TIP -> x = 254
#   Node 3923: TIP -> x = 255
#   Node 3969: TIP -> x = 256
#   Node 4069: TIP -> x = 257
#   Node 4147: TIP -> x = 258
#   Node 4210: TIP -> x = 259
#   Node 4245: TIP -> x = 260
#   Node 4324: TIP -> x = 261
#   Node 4476: TIP -> x = 262
#   Node 4525: TIP -> x = 263
#   Node 4564: TIP -> x = 264
#   Node 4579: TIP -> x = 265
#   Node 4636: TIP -> x = 266
#   Node 4679: TIP -> x = 267
#   Node 4735: TIP -> x = 268
#   Node 4740: TIP -> x = 269
#   Node 9170: pushed children [np.int32(4971), np.int32(4912), np.int32(4716), np.int32(4693), np.int32(4419), np.int32(4137), np.int32(3773), np.int32(3770), np.int32(3485), np.int32(3478), np.int32(3012), np.int32(2902), np.int32(2646), np.int32(2524), np.int32(2372), np.int32(2119), np.int32(1556), np.int32(1154), np.int32(998), np.int32(868), np.int32(816), np.int32(726), np.int32(408), np.int32(195), np.int32(98), np.int32(24)] (reversed)
#   Node 24: TIP -> x = 270
#   Node 98: TIP -> x = 271
#   Node 195: TIP -> x = 272
#   Node 408: TIP -> x = 273
#   Node 726: TIP -> x = 274
#   Node 816: TIP -> x = 275
#   Node 868: TIP -> x = 276
#   Node 998: TIP -> x = 277
#   Node 1154: TIP -> x = 278
#   Node 1556: TIP -> x = 279
#   Node 2119: TIP -> x = 280
#   Node 2372: TIP -> x = 281
#   Node 2524: TIP -> x = 282
#   Node 2646: TIP -> x = 283
#   Node 2902: TIP -> x = 284
#   Node 3012: TIP -> x = 285
#   Node 3478: TIP -> x = 286
#   Node 3485: TIP -> x = 287
#   Node 3770: TIP -> x = 288
#   Node 3773: TIP -> x = 289
#   Node 4137: TIP -> x = 290
#   Node 4419: TIP -> x = 291
#   Node 4693: TIP -> x = 292
#   Node 4716: TIP -> x = 293
#   Node 4912: TIP -> x = 294
#   Node 4971: TIP -> x = 295
#   Node 9170: INTERNAL, children_x=[np.float32(270.0), np.float32(271.0), np.float32(272.0), np.float32(273.0), np.float32(274.0), np.float32(275.0), np.float32(276.0), np.float32(277.0), np.float32(278.0), np.float32(279.0), np.float32(280.0), np.float32(281.0), np.float32(282.0), np.float32(283.0), np.float32(284.0), np.float32(285.0), np.float32(286.0), np.float32(287.0), np.float32(288.0), np.float32(289.0), np.float32(290.0), np.float32(291.0), np.float32(292.0), np.float32(293.0), np.float32(294.0), np.float32(295.0)], min=270.00, max=295.00 -> x = 282.50
#   Node 93065: pushed children [np.int32(2287), np.int32(219)] (reversed)
#   Node 219: TIP -> x = 296
#   Node 2287: TIP -> x = 297
#   Node 93065: INTERNAL, children_x=[np.float32(296.0), np.float32(297.0)], min=296.00, max=297.00 -> x = 296.50
#   Node 93759: pushed children [np.int32(3516), np.int32(1165)] (reversed)
#   Node 1165: TIP -> x = 298
#   Node 3516: TIP -> x = 299
#   Node 93759: INTERNAL, children_x=[np.float32(298.0), np.float32(299.0)], min=298.00, max=299.00 -> x = 298.50
#   Node 95588: INTERNAL, children_x=[np.float32(221.0), np.float32(222.0), np.float32(223.0), np.float32(224.0), np.float32(225.0), np.float32(226.0), np.float32(227.0), np.float32(228.0), np.float32(229.0), np.float32(230.0), np.float32(231.0), np.float32(232.0), np.float32(233.0), np.float32(234.0), np.float32(235.0), np.float32(236.0), np.float32(237.0), np.float32(238.0), np.float32(239.0), np.float32(240.0), np.float32(241.0), np.float32(242.0), np.float32(243.0), np.float32(244.0), np.float32(245.0), np.float32(246.0), np.float32(247.0), np.float32(248.0), np.float32(249.0), np.float32(250.0), np.float32(251.0), np.float32(252.0), np.float32(253.0), np.float32(254.0), np.float32(255.0), np.float32(256.0), np.float32(257.0), np.float32(258.0), np.float32(259.0), np.float32(260.0), np.float32(261.0), np.float32(262.0), np.float32(263.0), np.float32(264.0), np.float32(265.0), np.float32(266.0), np.float32(267.0), np.float32(268.0), np.float32(269.0), np.float32(282.5), np.float32(296.5), np.float32(298.5)], min=221.00, max=298.50 -> x = 259.75
#   Node 108561: pushed children [np.int32(3098), np.int32(2759), np.int32(2507), np.int32(349), np.int32(276)] (reversed)
#   Node 276: TIP -> x = 300
#   Node 349: TIP -> x = 301
#   Node 2507: TIP -> x = 302
#   Node 2759: TIP -> x = 303
#   Node 3098: TIP -> x = 304
#   Node 108561: INTERNAL, children_x=[np.float32(300.0), np.float32(301.0), np.float32(302.0), np.float32(303.0), np.float32(304.0)], min=300.00, max=304.00 -> x = 302.00
#   Node 109720: pushed children [np.int32(4584), np.int32(4553), np.int32(4407), np.int32(4387), np.int32(4295), np.int32(4120), np.int32(4091), np.int32(4082), np.int32(2676), np.int32(2489), np.int32(2333), np.int32(2201), np.int32(2037), np.int32(2018), np.int32(709)] (reversed)
#   Node 709: TIP -> x = 305
#   Node 2018: TIP -> x = 306
#   Node 2037: TIP -> x = 307
#   Node 2201: TIP -> x = 308
#   Node 2333: TIP -> x = 309
#   Node 2489: TIP -> x = 310
#   Node 2676: TIP -> x = 311
#   Node 4082: TIP -> x = 312
#   Node 4091: TIP -> x = 313
#   Node 4120: TIP -> x = 314
#   Node 4295: TIP -> x = 315
#   Node 4387: TIP -> x = 316
#   Node 4407: TIP -> x = 317
#   Node 4553: TIP -> x = 318
#   Node 4584: TIP -> x = 319
#   Node 109720: INTERNAL, children_x=[np.float32(305.0), np.float32(306.0), np.float32(307.0), np.float32(308.0), np.float32(309.0), np.float32(310.0), np.float32(311.0), np.float32(312.0), np.float32(313.0), np.float32(314.0), np.float32(315.0), np.float32(316.0), np.float32(317.0), np.float32(318.0), np.float32(319.0)], min=305.00, max=319.00 -> x = 312.00
#   Node 114742: pushed children [np.int32(60219), np.int32(4549), np.int32(4547), np.int32(4194), np.int32(3528), np.int32(3200), np.int32(3163), np.int32(2824), np.int32(2652), np.int32(2222), np.int32(2110), np.int32(1924), np.int32(1352), np.int32(1149), np.int32(814), np.int32(203), np.int32(189), np.int32(174)] (reversed)
#   Node 174: TIP -> x = 320
#   Node 189: TIP -> x = 321
#   Node 203: TIP -> x = 322
#   Node 814: TIP -> x = 323
#   Node 1149: TIP -> x = 324
#   Node 1352: TIP -> x = 325
#   Node 1924: TIP -> x = 326
#   Node 2110: TIP -> x = 327
#   Node 2222: TIP -> x = 328
#   Node 2652: TIP -> x = 329
#   Node 2824: TIP -> x = 330
#   Node 3163: TIP -> x = 331
#   Node 3200: TIP -> x = 332
#   Node 3528: TIP -> x = 333
#   Node 4194: TIP -> x = 334
#   Node 4547: TIP -> x = 335
#   Node 4549: TIP -> x = 336
#   Node 60219: pushed children [np.int32(4847), np.int32(4671), np.int32(4073), np.int32(3843), np.int32(2335), np.int32(326), np.int32(222), np.int32(186), np.int32(121)] (reversed)
#   Node 121: TIP -> x = 337
#   Node 186: TIP -> x = 338
#   Node 222: TIP -> x = 339
#   Node 326: TIP -> x = 340
#   Node 2335: TIP -> x = 341
#   Node 3843: TIP -> x = 342
#   Node 4073: TIP -> x = 343
#   Node 4671: TIP -> x = 344
#   Node 4847: TIP -> x = 345
#   Node 60219: INTERNAL, children_x=[np.float32(337.0), np.float32(338.0), np.float32(339.0), np.float32(340.0), np.float32(341.0), np.float32(342.0), np.float32(343.0), np.float32(344.0), np.float32(345.0)], min=337.00, max=345.00 -> x = 341.00
#   Node 114742: INTERNAL, children_x=[np.float32(320.0), np.float32(321.0), np.float32(322.0), np.float32(323.0), np.float32(324.0), np.float32(325.0), np.float32(326.0), np.float32(327.0), np.float32(328.0), np.float32(329.0), np.float32(330.0), np.float32(331.0), np.float32(332.0), np.float32(333.0), np.float32(334.0), np.float32(335.0), np.float32(336.0), np.float32(341.0)], min=320.00, max=341.00 -> x = 330.50
#   Node 115787: pushed children [np.int32(4243), np.int32(4216), np.int32(3542)] (reversed)
#   Node 3542: TIP -> x = 346
#   Node 4216: TIP -> x = 347
#   Node 4243: TIP -> x = 348
#   Node 115787: INTERNAL, children_x=[np.float32(346.0), np.float32(347.0), np.float32(348.0)], min=346.00, max=348.00 -> x = 347.00
#   Node 124828: pushed children [np.int32(93740), np.int32(4902), np.int32(4818), np.int32(4756), np.int32(4669), np.int32(4638), np.int32(4596), np.int32(4582), np.int32(4554), np.int32(4346), np.int32(4329), np.int32(4290), np.int32(4178), np.int32(4140), np.int32(4100), np.int32(4057), np.int32(3578), np.int32(3520), np.int32(3505), np.int32(3491), np.int32(3435), np.int32(3399), np.int32(3389), np.int32(3360), np.int32(3319), np.int32(3277), np.int32(3229), np.int32(3081), np.int32(3064), np.int32(2678), np.int32(2616), np.int32(2589), np.int32(2580), np.int32(2374), np.int32(2241), np.int32(2226), np.int32(2204), np.int32(2178), np.int32(2121), np.int32(2028), np.int32(1880), np.int32(1870), np.int32(1867), np.int32(1736), np.int32(1540), np.int32(1480), np.int32(1261), np.int32(951), np.int32(813), np.int32(801), np.int32(769), np.int32(765), np.int32(731), np.int32(714), np.int32(703), np.int32(256), np.int32(239), np.int32(168), np.int32(130), np.int32(50), np.int32(33)] (reversed)
#   Node 33: TIP -> x = 349
#   Node 50: TIP -> x = 350
#   Node 130: TIP -> x = 351
#   Node 168: TIP -> x = 352
#   Node 239: TIP -> x = 353
#   Node 256: TIP -> x = 354
#   Node 703: TIP -> x = 355
#   Node 714: TIP -> x = 356
#   Node 731: TIP -> x = 357
#   Node 765: TIP -> x = 358
#   Node 769: TIP -> x = 359
#   Node 801: TIP -> x = 360
#   Node 813: TIP -> x = 361
#   Node 951: TIP -> x = 362
#   Node 1261: TIP -> x = 363
#   Node 1480: TIP -> x = 364
#   Node 1540: TIP -> x = 365
#   Node 1736: TIP -> x = 366
#   Node 1867: TIP -> x = 367
#   Node 1870: TIP -> x = 368
#   Node 1880: TIP -> x = 369
#   Node 2028: TIP -> x = 370
#   Node 2121: TIP -> x = 371
#   Node 2178: TIP -> x = 372
#   Node 2204: TIP -> x = 373
#   Node 2226: TIP -> x = 374
#   Node 2241: TIP -> x = 375
#   Node 2374: TIP -> x = 376
#   Node 2580: TIP -> x = 377
#   Node 2589: TIP -> x = 378
#   Node 2616: TIP -> x = 379
#   Node 2678: TIP -> x = 380
#   Node 3064: TIP -> x = 381
#   Node 3081: TIP -> x = 382
#   Node 3229: TIP -> x = 383
#   Node 3277: TIP -> x = 384
#   Node 3319: TIP -> x = 385
#   Node 3360: TIP -> x = 386
#   Node 3389: TIP -> x = 387
#   Node 3399: TIP -> x = 388
#   Node 3435: TIP -> x = 389
#   Node 3491: TIP -> x = 390
#   Node 3505: TIP -> x = 391
#   Node 3520: TIP -> x = 392
#   Node 3578: TIP -> x = 393
#   Node 4057: TIP -> x = 394
#   Node 4100: TIP -> x = 395
#   Node 4140: TIP -> x = 396
#   Node 4178: TIP -> x = 397
#   Node 4290: TIP -> x = 398
#   Node 4329: TIP -> x = 399
#   Node 4346: TIP -> x = 400
#   Node 4554: TIP -> x = 401
#   Node 4582: TIP -> x = 402
#   Node 4596: TIP -> x = 403
#   Node 4638: TIP -> x = 404
#   Node 4669: TIP -> x = 405
#   Node 4756: TIP -> x = 406
#   Node 4818: TIP -> x = 407
#   Node 4902: TIP -> x = 408
#   Node 93740: pushed children [np.int32(3487), np.int32(946)] (reversed)
#   Node 946: TIP -> x = 409
#   Node 3487: TIP -> x = 410
#   Node 93740: INTERNAL, children_x=[np.float32(409.0), np.float32(410.0)], min=409.00, max=410.00 -> x = 409.50
#   Node 124828: INTERNAL, children_x=[np.float32(349.0), np.float32(350.0), np.float32(351.0), np.float32(352.0), np.float32(353.0), np.float32(354.0), np.float32(355.0), np.float32(356.0), np.float32(357.0), np.float32(358.0), np.float32(359.0), np.float32(360.0), np.float32(361.0), np.float32(362.0), np.float32(363.0), np.float32(364.0), np.float32(365.0), np.float32(366.0), np.float32(367.0), np.float32(368.0), np.float32(369.0), np.float32(370.0), np.float32(371.0), np.float32(372.0), np.float32(373.0), np.float32(374.0), np.float32(375.0), np.float32(376.0), np.float32(377.0), np.float32(378.0), np.float32(379.0), np.float32(380.0), np.float32(381.0), np.float32(382.0), np.float32(383.0), np.float32(384.0), np.float32(385.0), np.float32(386.0), np.float32(387.0), np.float32(388.0), np.float32(389.0), np.float32(390.0), np.float32(391.0), np.float32(392.0), np.float32(393.0), np.float32(394.0), np.float32(395.0), np.float32(396.0), np.float32(397.0), np.float32(398.0), np.float32(399.0), np.float32(400.0), np.float32(401.0), np.float32(402.0), np.float32(403.0), np.float32(404.0), np.float32(405.0), np.float32(406.0), np.float32(407.0), np.float32(408.0), np.float32(409.5)], min=349.00, max=409.50 -> x = 379.25
#   Node 137801: pushed children [np.int32(2469), np.int32(1954)] (reversed)
#   Node 1954: TIP -> x = 411
#   Node 2469: TIP -> x = 412
#   Node 137801: INTERNAL, children_x=[np.float32(411.0), np.float32(412.0)], min=411.00, max=412.00 -> x = 411.50
#   Node 139959: pushed children [np.int32(116859), np.int32(115324), np.int32(4851), np.int32(4484), np.int32(4466), np.int32(4414), np.int32(4337), np.int32(4237), np.int32(4211), np.int32(4001), np.int32(3956), np.int32(3915), np.int32(3801), np.int32(3795), np.int32(3775), np.int32(3772), np.int32(3767), np.int32(3687), np.int32(3298), np.int32(3249), np.int32(2772), np.int32(2651), np.int32(2605), np.int32(2604), np.int32(2598), np.int32(2497), np.int32(2324), np.int32(2252), np.int32(2250), np.int32(2229), np.int32(2227), np.int32(2136), np.int32(2135), np.int32(2102), np.int32(2024), np.int32(1997), np.int32(1837), np.int32(1739), np.int32(1671), np.int32(1626), np.int32(1407), np.int32(881), np.int32(806), np.int32(647), np.int32(519), np.int32(213)] (reversed)
#   Node 213: TIP -> x = 413
#   Node 519: TIP -> x = 414
#   Node 647: TIP -> x = 415
#   Node 806: TIP -> x = 416
#   Node 881: TIP -> x = 417
#   Node 1407: TIP -> x = 418
#   Node 1626: TIP -> x = 419
#   Node 1671: TIP -> x = 420
#   Node 1739: TIP -> x = 421
#   Node 1837: TIP -> x = 422
#   Node 1997: TIP -> x = 423
#   Node 2024: TIP -> x = 424
#   Node 2102: TIP -> x = 425
#   Node 2135: TIP -> x = 426
#   Node 2136: TIP -> x = 427
#   Node 2227: TIP -> x = 428
#   Node 2229: TIP -> x = 429
#   Node 2250: TIP -> x = 430
#   Node 2252: TIP -> x = 431
#   Node 2324: TIP -> x = 432
#   Node 2497: TIP -> x = 433
#   Node 2598: TIP -> x = 434
#   Node 2604: TIP -> x = 435
#   Node 2605: TIP -> x = 436
#   Node 2651: TIP -> x = 437
#   Node 2772: TIP -> x = 438
#   Node 3249: TIP -> x = 439
#   Node 3298: TIP -> x = 440
#   Node 3687: TIP -> x = 441
#   Node 3767: TIP -> x = 442
#   Node 3772: TIP -> x = 443
#   Node 3775: TIP -> x = 444
#   Node 3795: TIP -> x = 445
#   Node 3801: TIP -> x = 446
#   Node 3915: TIP -> x = 447
#   Node 3956: TIP -> x = 448
#   Node 4001: TIP -> x = 449
#   Node 4211: TIP -> x = 450
#   Node 4237: TIP -> x = 451
#   Node 4337: TIP -> x = 452
#   Node 4414: TIP -> x = 453
#   Node 4466: TIP -> x = 454
#   Node 4484: TIP -> x = 455
#   Node 4851: TIP -> x = 456
#   Node 115324: pushed children [np.int32(69572), np.int32(4487), np.int32(4223), np.int32(4177), np.int32(4152), np.int32(4142), np.int32(4125), np.int32(4107), np.int32(3771), np.int32(2685), np.int32(2620), np.int32(2522), np.int32(2308), np.int32(1863)] (reversed)
#   Node 1863: TIP -> x = 457
#   Node 2308: TIP -> x = 458
#   Node 2522: TIP -> x = 459
#   Node 2620: TIP -> x = 460
#   Node 2685: TIP -> x = 461
#   Node 3771: TIP -> x = 462
#   Node 4107: TIP -> x = 463
#   Node 4125: TIP -> x = 464
#   Node 4142: TIP -> x = 465
#   Node 4152: TIP -> x = 466
#   Node 4177: TIP -> x = 467
#   Node 4223: TIP -> x = 468
#   Node 4487: TIP -> x = 469
#   Node 69572: pushed children [np.int32(4215), np.int32(3777), np.int32(3538), np.int32(3466), np.int32(2655), np.int32(1784), np.int32(1369)] (reversed)
#   Node 1369: TIP -> x = 470
#   Node 1784: TIP -> x = 471
#   Node 2655: TIP -> x = 472
#   Node 3466: TIP -> x = 473
#   Node 3538: TIP -> x = 474
#   Node 3777: TIP -> x = 475
#   Node 4215: TIP -> x = 476
#   Node 69572: INTERNAL, children_x=[np.float32(470.0), np.float32(471.0), np.float32(472.0), np.float32(473.0), np.float32(474.0), np.float32(475.0), np.float32(476.0)], min=470.00, max=476.00 -> x = 473.00
#   Node 115324: INTERNAL, children_x=[np.float32(457.0), np.float32(458.0), np.float32(459.0), np.float32(460.0), np.float32(461.0), np.float32(462.0), np.float32(463.0), np.float32(464.0), np.float32(465.0), np.float32(466.0), np.float32(467.0), np.float32(468.0), np.float32(469.0), np.float32(473.0)], min=457.00, max=473.00 -> x = 465.00
#   Node 116859: pushed children [np.int32(4393), np.int32(2517)] (reversed)
#   Node 2517: TIP -> x = 477
#   Node 4393: TIP -> x = 478
#   Node 116859: INTERNAL, children_x=[np.float32(477.0), np.float32(478.0)], min=477.00, max=478.00 -> x = 477.50
#   Node 139959: INTERNAL, children_x=[np.float32(413.0), np.float32(414.0), np.float32(415.0), np.float32(416.0), np.float32(417.0), np.float32(418.0), np.float32(419.0), np.float32(420.0), np.float32(421.0), np.float32(422.0), np.float32(423.0), np.float32(424.0), np.float32(425.0), np.float32(426.0), np.float32(427.0), np.float32(428.0), np.float32(429.0), np.float32(430.0), np.float32(431.0), np.float32(432.0), np.float32(433.0), np.float32(434.0), np.float32(435.0), np.float32(436.0), np.float32(437.0), np.float32(438.0), np.float32(439.0), np.float32(440.0), np.float32(441.0), np.float32(442.0), np.float32(443.0), np.float32(444.0), np.float32(445.0), np.float32(446.0), np.float32(447.0), np.float32(448.0), np.float32(449.0), np.float32(450.0), np.float32(451.0), np.float32(452.0), np.float32(453.0), np.float32(454.0), np.float32(455.0), np.float32(456.0), np.float32(465.0), np.float32(477.5)], min=413.00, max=477.50 -> x = 445.25
#   Node 140174: pushed children [np.int32(4225), np.int32(4026), np.int32(3699), np.int32(2107), np.int32(1436), np.int32(728), np.int32(719)] (reversed)
#   Node 719: TIP -> x = 479
#   Node 728: TIP -> x = 480
#   Node 1436: TIP -> x = 481
#   Node 2107: TIP -> x = 482
#   Node 3699: TIP -> x = 483
#   Node 4026: TIP -> x = 484
#   Node 4225: TIP -> x = 485
#   Node 140174: INTERNAL, children_x=[np.float32(479.0), np.float32(480.0), np.float32(481.0), np.float32(482.0), np.float32(483.0), np.float32(484.0), np.float32(485.0)], min=479.00, max=485.00 -> x = 482.00
#   Node 146990: pushed children [np.int32(33944), np.int32(24508), np.int32(5003), np.int32(4987), np.int32(4711), np.int32(4655), np.int32(4319), np.int32(4280), np.int32(4220), np.int32(4212), np.int32(4185), np.int32(4180), np.int32(4168), np.int32(4157), np.int32(4098), np.int32(4067), np.int32(3976), np.int32(3557), np.int32(3246), np.int32(3187), np.int32(3125), np.int32(2962), np.int32(2951), np.int32(2674), np.int32(2656), np.int32(2568), np.int32(2492), np.int32(2436), np.int32(2428), np.int32(2426), np.int32(2412), np.int32(2392), np.int32(2388), np.int32(2366), np.int32(2365), np.int32(2318), np.int32(2284), np.int32(2196), np.int32(2150), np.int32(2071), np.int32(2062), np.int32(1876), np.int32(1838), np.int32(1795), np.int32(1785), np.int32(1644), np.int32(1368), np.int32(987), np.int32(971), np.int32(932), np.int32(893), np.int32(832), np.int32(794), np.int32(549), np.int32(441), np.int32(400), np.int32(67)] (reversed)
#   Node 67: TIP -> x = 486
#   Node 400: TIP -> x = 487
#   Node 441: TIP -> x = 488
#   Node 549: TIP -> x = 489
#   Node 794: TIP -> x = 490
#   Node 832: TIP -> x = 491
#   Node 893: TIP -> x = 492
#   Node 932: TIP -> x = 493
#   Node 971: TIP -> x = 494
#   Node 987: TIP -> x = 495
#   Node 1368: TIP -> x = 496
#   Node 1644: TIP -> x = 497
#   Node 1785: TIP -> x = 498
#   Node 1795: TIP -> x = 499
#   Node 1838: TIP -> x = 500
#   Node 1876: TIP -> x = 501
#   Node 2062: TIP -> x = 502
#   Node 2071: TIP -> x = 503
#   Node 2150: TIP -> x = 504
#   Node 2196: TIP -> x = 505
#   Node 2284: TIP -> x = 506
#   Node 2318: TIP -> x = 507
#   Node 2365: TIP -> x = 508
#   Node 2366: TIP -> x = 509
#   Node 2388: TIP -> x = 510
#   Node 2392: TIP -> x = 511
#   Node 2412: TIP -> x = 512
#   Node 2426: TIP -> x = 513
#   Node 2428: TIP -> x = 514
#   Node 2436: TIP -> x = 515
#   Node 2492: TIP -> x = 516
#   Node 2568: TIP -> x = 517
#   Node 2656: TIP -> x = 518
#   Node 2674: TIP -> x = 519
#   Node 2951: TIP -> x = 520
#   Node 2962: TIP -> x = 521
#   Node 3125: TIP -> x = 522
#   Node 3187: TIP -> x = 523
#   Node 3246: TIP -> x = 524
#   Node 3557: TIP -> x = 525
#   Node 3976: TIP -> x = 526
#   Node 4067: TIP -> x = 527
#   Node 4098: TIP -> x = 528
#   Node 4157: TIP -> x = 529
#   Node 4168: TIP -> x = 530
#   Node 4180: TIP -> x = 531
#   Node 4185: TIP -> x = 532
#   Node 4212: TIP -> x = 533
#   Node 4220: TIP -> x = 534
#   Node 4280: TIP -> x = 535
#   Node 4319: TIP -> x = 536
#   Node 4655: TIP -> x = 537
#   Node 4711: TIP -> x = 538
#   Node 4987: TIP -> x = 539
#   Node 5003: TIP -> x = 540
#   Node 24508: pushed children [np.int32(3138), np.int32(3111)] (reversed)
#   Node 3111: TIP -> x = 541
#   Node 3138: TIP -> x = 542
#   Node 24508: INTERNAL, children_x=[np.float32(541.0), np.float32(542.0)], min=541.00, max=542.00 -> x = 541.50
#   Node 33944: pushed children [np.int32(4576), np.int32(4382), np.int32(4314), np.int32(4296), np.int32(4257), np.int32(4175), np.int32(4064), np.int32(3966), np.int32(3955), np.int32(3755), np.int32(3499), np.int32(3411), np.int32(3310), np.int32(2927), np.int32(2650), np.int32(2564), np.int32(2541), np.int32(2338), np.int32(2331), np.int32(2129), np.int32(1992), np.int32(1737), np.int32(1498), np.int32(1485), np.int32(1382), np.int32(1373), np.int32(1206), np.int32(1139), np.int32(591), np.int32(361), np.int32(344), np.int32(91)] (reversed)
#   Node 91: TIP -> x = 543
#   Node 344: TIP -> x = 544
#   Node 361: TIP -> x = 545
#   Node 591: TIP -> x = 546
#   Node 1139: TIP -> x = 547
#   Node 1206: TIP -> x = 548
#   Node 1373: TIP -> x = 549
#   Node 1382: TIP -> x = 550
#   Node 1485: TIP -> x = 551
#   Node 1498: TIP -> x = 552
#   Node 1737: TIP -> x = 553
#   Node 1992: TIP -> x = 554
#   Node 2129: TIP -> x = 555
#   Node 2331: TIP -> x = 556
#   Node 2338: TIP -> x = 557
#   Node 2541: TIP -> x = 558
#   Node 2564: TIP -> x = 559
#   Node 2650: TIP -> x = 560
#   Node 2927: TIP -> x = 561
#   Node 3310: TIP -> x = 562
#   Node 3411: TIP -> x = 563
#   Node 3499: TIP -> x = 564
#   Node 3755: TIP -> x = 565
#   Node 3955: TIP -> x = 566
#   Node 3966: TIP -> x = 567
#   Node 4064: TIP -> x = 568
#   Node 4175: TIP -> x = 569
#   Node 4257: TIP -> x = 570
#   Node 4296: TIP -> x = 571
#   Node 4314: TIP -> x = 572
#   Node 4382: TIP -> x = 573
#   Node 4576: TIP -> x = 574
#   Node 33944: INTERNAL, children_x=[np.float32(543.0), np.float32(544.0), np.float32(545.0), np.float32(546.0), np.float32(547.0), np.float32(548.0), np.float32(549.0), np.float32(550.0), np.float32(551.0), np.float32(552.0), np.float32(553.0), np.float32(554.0), np.float32(555.0), np.float32(556.0), np.float32(557.0), np.float32(558.0), np.float32(559.0), np.float32(560.0), np.float32(561.0), np.float32(562.0), np.float32(563.0), np.float32(564.0), np.float32(565.0), np.float32(566.0), np.float32(567.0), np.float32(568.0), np.float32(569.0), np.float32(570.0), np.float32(571.0), np.float32(572.0), np.float32(573.0), np.float32(574.0)], min=543.00, max=574.00 -> x = 558.50
#   Node 146990: INTERNAL, children_x=[np.float32(486.0), np.float32(487.0), np.float32(488.0), np.float32(489.0), np.float32(490.0), np.float32(491.0), np.float32(492.0), np.float32(493.0), np.float32(494.0), np.float32(495.0), np.float32(496.0), np.float32(497.0), np.float32(498.0), np.float32(499.0), np.float32(500.0), np.float32(501.0), np.float32(502.0), np.float32(503.0), np.float32(504.0), np.float32(505.0), np.float32(506.0), np.float32(507.0), np.float32(508.0), np.float32(509.0), np.float32(510.0), np.float32(511.0), np.float32(512.0), np.float32(513.0), np.float32(514.0), np.float32(515.0), np.float32(516.0), np.float32(517.0), np.float32(518.0), np.float32(519.0), np.float32(520.0), np.float32(521.0), np.float32(522.0), np.float32(523.0), np.float32(524.0), np.float32(525.0), np.float32(526.0), np.float32(527.0), np.float32(528.0), np.float32(529.0), np.float32(530.0), np.float32(531.0), np.float32(532.0), np.float32(533.0), np.float32(534.0), np.float32(535.0), np.float32(536.0), np.float32(537.0), np.float32(538.0), np.float32(539.0), np.float32(540.0), np.float32(541.5), np.float32(558.5)], min=486.00, max=558.50 -> x = 522.25
#   Node 151820: pushed children [np.int32(137984), np.int32(4870), np.int32(4791), np.int32(4360), np.int32(4045), np.int32(3997), np.int32(3832), np.int32(3723), np.int32(3673), np.int32(3629), np.int32(3608), np.int32(3568), np.int32(3562), np.int32(3553), np.int32(3480), np.int32(3470), np.int32(3293), np.int32(3236), np.int32(3131), np.int32(3040), np.int32(2963), np.int32(2953), np.int32(2949), np.int32(2944), np.int32(2929), np.int32(2905), np.int32(2883), np.int32(2842), np.int32(2778), np.int32(2486), np.int32(2093), np.int32(2060), np.int32(1826), np.int32(1807), np.int32(1799), np.int32(1723), np.int32(1666), np.int32(1638), np.int32(1634), np.int32(1619), np.int32(1550), np.int32(1510), np.int32(1415), np.int32(1409), np.int32(1345), np.int32(1296), np.int32(1226), np.int32(1216), np.int32(1152), np.int32(1144), np.int32(1056), np.int32(899), np.int32(411), np.int32(405), np.int32(308), np.int32(283), np.int32(230), np.int32(23)] (reversed)
#   Node 23: TIP -> x = 575
#   Node 230: TIP -> x = 576
#   Node 283: TIP -> x = 577
#   Node 308: TIP -> x = 578
#   Node 405: TIP -> x = 579
#   Node 411: TIP -> x = 580
#   Node 899: TIP -> x = 581
#   Node 1056: TIP -> x = 582
#   Node 1144: TIP -> x = 583
#   Node 1152: TIP -> x = 584
#   Node 1216: TIP -> x = 585
#   Node 1226: TIP -> x = 586
#   Node 1296: TIP -> x = 587
#   Node 1345: TIP -> x = 588
#   Node 1409: TIP -> x = 589
#   Node 1415: TIP -> x = 590
#   Node 1510: TIP -> x = 591
#   Node 1550: TIP -> x = 592
#   Node 1619: TIP -> x = 593
#   Node 1634: TIP -> x = 594
#   Node 1638: TIP -> x = 595
#   Node 1666: TIP -> x = 596
#   Node 1723: TIP -> x = 597
#   Node 1799: TIP -> x = 598
#   Node 1807: TIP -> x = 599
#   Node 1826: TIP -> x = 600
#   Node 2060: TIP -> x = 601
#   Node 2093: TIP -> x = 602
#   Node 2486: TIP -> x = 603
#   Node 2778: TIP -> x = 604
#   Node 2842: TIP -> x = 605
#   Node 2883: TIP -> x = 606
#   Node 2905: TIP -> x = 607
#   Node 2929: TIP -> x = 608
#   Node 2944: TIP -> x = 609
#   Node 2949: TIP -> x = 610
#   Node 2953: TIP -> x = 611
#   Node 2963: TIP -> x = 612
#   Node 3040: TIP -> x = 613
#   Node 3131: TIP -> x = 614
#   Node 3236: TIP -> x = 615
#   Node 3293: TIP -> x = 616
#   Node 3470: TIP -> x = 617
#   Node 3480: TIP -> x = 618
#   Node 3553: TIP -> x = 619
#   Node 3562: TIP -> x = 620
#   Node 3568: TIP -> x = 621
#   Node 3608: TIP -> x = 622
#   Node 3629: TIP -> x = 623
#   Node 3673: TIP -> x = 624
#   Node 3723: TIP -> x = 625
#   Node 3832: TIP -> x = 626
#   Node 3997: TIP -> x = 627
#   Node 4045: TIP -> x = 628
#   Node 4360: TIP -> x = 629
#   Node 4791: TIP -> x = 630
#   Node 4870: TIP -> x = 631
#   Node 137984: pushed children [np.int32(3256), np.int32(1592)] (reversed)
#   Node 1592: TIP -> x = 632
#   Node 3256: TIP -> x = 633
#   Node 137984: INTERNAL, children_x=[np.float32(632.0), np.float32(633.0)], min=632.00, max=633.00 -> x = 632.50
#   Node 151820: INTERNAL, children_x=[np.float32(575.0), np.float32(576.0), np.float32(577.0), np.float32(578.0), np.float32(579.0), np.float32(580.0), np.float32(581.0), np.float32(582.0), np.float32(583.0), np.float32(584.0), np.float32(585.0), np.float32(586.0), np.float32(587.0), np.float32(588.0), np.float32(589.0), np.float32(590.0), np.float32(591.0), np.float32(592.0), np.float32(593.0), np.float32(594.0), np.float32(595.0), np.float32(596.0), np.float32(597.0), np.float32(598.0), np.float32(599.0), np.float32(600.0), np.float32(601.0), np.float32(602.0), np.float32(603.0), np.float32(604.0), np.float32(605.0), np.float32(606.0), np.float32(607.0), np.float32(608.0), np.float32(609.0), np.float32(610.0), np.float32(611.0), np.float32(612.0), np.float32(613.0), np.float32(614.0), np.float32(615.0), np.float32(616.0), np.float32(617.0), np.float32(618.0), np.float32(619.0), np.float32(620.0), np.float32(621.0), np.float32(622.0), np.float32(623.0), np.float32(624.0), np.float32(625.0), np.float32(626.0), np.float32(627.0), np.float32(628.0), np.float32(629.0), np.float32(630.0), np.float32(631.0), np.float32(632.5)], min=575.00, max=632.50 -> x = 603.75
#   Node 180379: pushed children [np.int32(117070), np.int32(107257), np.int32(97661), np.int32(96626), np.int32(19877), np.int32(14558), np.int32(4983), np.int32(4897), np.int32(4778), np.int32(4683), np.int32(4627), np.int32(4589), np.int32(4453), np.int32(4378), np.int32(4373), np.int32(4356), np.int32(4122), np.int32(4065), np.int32(4022), np.int32(4014), np.int32(3989), np.int32(3973), np.int32(3946), np.int32(3924), np.int32(3908), np.int32(3839), np.int32(3819), np.int32(3786), np.int32(3714), np.int32(3711), np.int32(3668), np.int32(3634), np.int32(3587), np.int32(3585), np.int32(3418), np.int32(3279), np.int32(3223), np.int32(3194), np.int32(3193), np.int32(3066), np.int32(3032), np.int32(2974), np.int32(2931), np.int32(2924), np.int32(2788), np.int32(2781), np.int32(2776), np.int32(2548), np.int32(2402), np.int32(2396), np.int32(2297), np.int32(2271), np.int32(2172), np.int32(2167), np.int32(2048), np.int32(2043), np.int32(2032), np.int32(1989), np.int32(1888), np.int32(1842), np.int32(1835), np.int32(1818), np.int32(1722), np.int32(1667), np.int32(1647), np.int32(1617), np.int32(1581), np.int32(1562), np.int32(1520), np.int32(1509), np.int32(1495), np.int32(1492), np.int32(1448), np.int32(1395), np.int32(1342), np.int32(1328), np.int32(1304), np.int32(1287), np.int32(1281), np.int32(1263), np.int32(1100), np.int32(1018), np.int32(955), np.int32(842), np.int32(819), np.int32(752), np.int32(674), np.int32(524), np.int32(512), np.int32(450), np.int32(438), np.int32(398), np.int32(357), np.int32(284), np.int32(41), np.int32(8)] (reversed)
#   Node 8: TIP -> x = 634
#   Node 41: TIP -> x = 635
#   Node 284: TIP -> x = 636
#   Node 357: TIP -> x = 637
#   Node 398: TIP -> x = 638
#   Node 438: TIP -> x = 639
#   Node 450: TIP -> x = 640
#   Node 512: TIP -> x = 641
#   Node 524: TIP -> x = 642
#   Node 674: TIP -> x = 643
#   Node 752: TIP -> x = 644
#   Node 819: TIP -> x = 645
#   Node 842: TIP -> x = 646
#   Node 955: TIP -> x = 647
#   Node 1018: TIP -> x = 648
#   Node 1100: TIP -> x = 649
#   Node 1263: TIP -> x = 650
#   Node 1281: TIP -> x = 651
#   Node 1287: TIP -> x = 652
#   Node 1304: TIP -> x = 653
#   Node 1328: TIP -> x = 654
#   Node 1342: TIP -> x = 655
#   Node 1395: TIP -> x = 656
#   Node 1448: TIP -> x = 657
#   Node 1492: TIP -> x = 658
#   Node 1495: TIP -> x = 659
#   Node 1509: TIP -> x = 660
#   Node 1520: TIP -> x = 661
#   Node 1562: TIP -> x = 662
#   Node 1581: TIP -> x = 663
#   Node 1617: TIP -> x = 664
#   Node 1647: TIP -> x = 665
#   Node 1667: TIP -> x = 666
#   Node 1722: TIP -> x = 667
#   Node 1818: TIP -> x = 668
#   Node 1835: TIP -> x = 669
#   Node 1842: TIP -> x = 670
#   Node 1888: TIP -> x = 671
#   Node 1989: TIP -> x = 672
#   Node 2032: TIP -> x = 673
#   Node 2043: TIP -> x = 674
#   Node 2048: TIP -> x = 675
#   Node 2167: TIP -> x = 676
#   Node 2172: TIP -> x = 677
#   Node 2271: TIP -> x = 678
#   Node 2297: TIP -> x = 679
#   Node 2396: TIP -> x = 680
#   Node 2402: TIP -> x = 681
#   Node 2548: TIP -> x = 682
#   Node 2776: TIP -> x = 683
#   Node 2781: TIP -> x = 684
#   Node 2788: TIP -> x = 685
#   Node 2924: TIP -> x = 686
#   Node 2931: TIP -> x = 687
#   Node 2974: TIP -> x = 688
#   Node 3032: TIP -> x = 689
#   Node 3066: TIP -> x = 690
#   Node 3193: TIP -> x = 691
#   Node 3194: TIP -> x = 692
#   Node 3223: TIP -> x = 693
#   Node 3279: TIP -> x = 694
#   Node 3418: TIP -> x = 695
#   Node 3585: TIP -> x = 696
#   Node 3587: TIP -> x = 697
#   Node 3634: TIP -> x = 698
#   Node 3668: TIP -> x = 699
#   Node 3711: TIP -> x = 700
#   Node 3714: TIP -> x = 701
#   Node 3786: TIP -> x = 702
#   Node 3819: TIP -> x = 703
#   Node 3839: TIP -> x = 704
#   Node 3908: TIP -> x = 705
#   Node 3924: TIP -> x = 706
#   Node 3946: TIP -> x = 707
#   Node 3973: TIP -> x = 708
#   Node 3989: TIP -> x = 709
#   Node 4014: TIP -> x = 710
#   Node 4022: TIP -> x = 711
#   Node 4065: TIP -> x = 712
#   Node 4122: TIP -> x = 713
#   Node 4356: TIP -> x = 714
#   Node 4373: TIP -> x = 715
#   Node 4378: TIP -> x = 716
#   Node 4453: TIP -> x = 717
#   Node 4589: TIP -> x = 718
#   Node 4627: TIP -> x = 719
#   Node 4683: TIP -> x = 720
#   Node 4778: TIP -> x = 721
#   Node 4897: TIP -> x = 722
#   Node 4983: TIP -> x = 723
#   Node 14558: pushed children [np.int32(4071), np.int32(3987), np.int32(2958), np.int32(2713), np.int32(184)] (reversed)
#   Node 184: TIP -> x = 724
#   Node 2713: TIP -> x = 725
#   Node 2958: TIP -> x = 726
#   Node 3987: TIP -> x = 727
#   Node 4071: TIP -> x = 728
#   Node 14558: INTERNAL, children_x=[np.float32(724.0), np.float32(725.0), np.float32(726.0), np.float32(727.0), np.float32(728.0)], min=724.00, max=728.00 -> x = 726.00
#   Node 19877: pushed children [np.int32(4840), np.int32(4701), np.int32(4202), np.int32(2379), np.int32(1696), np.int32(1331), np.int32(172), np.int32(63)] (reversed)
#   Node 63: TIP -> x = 729
#   Node 172: TIP -> x = 730
#   Node 1331: TIP -> x = 731
#   Node 1696: TIP -> x = 732
#   Node 2379: TIP -> x = 733
#   Node 4202: TIP -> x = 734
#   Node 4701: TIP -> x = 735
#   Node 4840: TIP -> x = 736
#   Node 19877: INTERNAL, children_x=[np.float32(729.0), np.float32(730.0), np.float32(731.0), np.float32(732.0), np.float32(733.0), np.float32(734.0), np.float32(735.0), np.float32(736.0)], min=729.00, max=736.00 -> x = 732.50
#   Node 96626: pushed children [np.int32(3713), np.int32(2140)] (reversed)
#   Node 2140: TIP -> x = 737
#   Node 3713: TIP -> x = 738
#   Node 96626: INTERNAL, children_x=[np.float32(737.0), np.float32(738.0)], min=737.00, max=738.00 -> x = 737.50
#   Node 97661: pushed children [np.int32(94024), np.int32(4941), np.int32(4853), np.int32(4817), np.int32(4715), np.int32(4600), np.int32(4597), np.int32(4483), np.int32(4444), np.int32(4439), np.int32(4431), np.int32(4429), np.int32(4358), np.int32(4025), np.int32(3948), np.int32(3932), np.int32(3925), np.int32(3877), np.int32(3864), np.int32(3726), np.int32(3697), np.int32(3677), np.int32(3674), np.int32(3590), np.int32(3570), np.int32(3566), np.int32(3475), np.int32(3445), np.int32(3404), np.int32(3385), np.int32(3025), np.int32(2947), np.int32(2873), np.int32(2850), np.int32(2763), np.int32(2750), np.int32(2710), np.int32(2450), np.int32(2307), np.int32(2288), np.int32(2153), np.int32(2151), np.int32(1959), np.int32(1940), np.int32(1796), np.int32(1731), np.int32(1713), np.int32(1572), np.int32(1542), np.int32(1541), np.int32(1531), np.int32(1502), np.int32(1475), np.int32(1447), np.int32(1434), np.int32(1429), np.int32(1378), np.int32(1376), np.int32(1300), np.int32(1258), np.int32(1168), np.int32(1129), np.int32(1121), np.int32(1098), np.int32(1035), np.int32(945), np.int32(885), np.int32(879), np.int32(838), np.int32(792), np.int32(694), np.int32(636), np.int32(625), np.int32(617), np.int32(461), np.int32(406), np.int32(378), np.int32(374)] (reversed)
#   Node 374: TIP -> x = 739
#   Node 378: TIP -> x = 740
#   Node 406: TIP -> x = 741
#   Node 461: TIP -> x = 742
#   Node 617: TIP -> x = 743
#   Node 625: TIP -> x = 744
#   Node 636: TIP -> x = 745
#   Node 694: TIP -> x = 746
#   Node 792: TIP -> x = 747
#   Node 838: TIP -> x = 748
#   Node 879: TIP -> x = 749
#   Node 885: TIP -> x = 750
#   Node 945: TIP -> x = 751
#   Node 1035: TIP -> x = 752
#   Node 1098: TIP -> x = 753
#   Node 1121: TIP -> x = 754
#   Node 1129: TIP -> x = 755
#   Node 1168: TIP -> x = 756
#   Node 1258: TIP -> x = 757
#   Node 1300: TIP -> x = 758
#   Node 1376: TIP -> x = 759
#   Node 1378: TIP -> x = 760
#   Node 1429: TIP -> x = 761
#   Node 1434: TIP -> x = 762
#   Node 1447: TIP -> x = 763
#   Node 1475: TIP -> x = 764
#   Node 1502: TIP -> x = 765
#   Node 1531: TIP -> x = 766
#   Node 1541: TIP -> x = 767
#   Node 1542: TIP -> x = 768
#   Node 1572: TIP -> x = 769
#   Node 1713: TIP -> x = 770
#   Node 1731: TIP -> x = 771
#   Node 1796: TIP -> x = 772
#   Node 1940: TIP -> x = 773
#   Node 1959: TIP -> x = 774
#   Node 2151: TIP -> x = 775
#   Node 2153: TIP -> x = 776
#   Node 2288: TIP -> x = 777
#   Node 2307: TIP -> x = 778
#   Node 2450: TIP -> x = 779
#   Node 2710: TIP -> x = 780
#   Node 2750: TIP -> x = 781
#   Node 2763: TIP -> x = 782
#   Node 2850: TIP -> x = 783
#   Node 2873: TIP -> x = 784
#   Node 2947: TIP -> x = 785
#   Node 3025: TIP -> x = 786
#   Node 3385: TIP -> x = 787
#   Node 3404: TIP -> x = 788
#   Node 3445: TIP -> x = 789
#   Node 3475: TIP -> x = 790
#   Node 3566: TIP -> x = 791
#   Node 3570: TIP -> x = 792
#   Node 3590: TIP -> x = 793
#   Node 3674: TIP -> x = 794
#   Node 3677: TIP -> x = 795
#   Node 3697: TIP -> x = 796
#   Node 3726: TIP -> x = 797
#   Node 3864: TIP -> x = 798
#   Node 3877: TIP -> x = 799
#   Node 3925: TIP -> x = 800
#   Node 3932: TIP -> x = 801
#   Node 3948: TIP -> x = 802
#   Node 4025: TIP -> x = 803
#   Node 4358: TIP -> x = 804
#   Node 4429: TIP -> x = 805
#   Node 4431: TIP -> x = 806
# ...
#   Node 408113: INTERNAL, children_x=[np.float32(4520.0), np.float32(4525.0), np.float32(4770.25)], min=4520.00, max=4770.25 -> x = 4645.12
#   Node 416274: INTERNAL, children_x=[np.float32(2975.0), np.float32(2976.0), np.float32(2977.0), np.float32(2978.0), np.float32(2979.0), np.float32(2980.0), np.float32(2981.0), np.float32(2982.0), np.float32(2983.0), np.float32(2984.0), np.float32(2985.0), np.float32(2986.0), np.float32(2987.0), np.float32(2988.0), np.float32(2989.0), np.float32(2990.0), np.float32(2991.0), np.float32(2992.0), np.float32(2993.0), np.float32(2994.0), np.float32(2995.0), np.float32(2996.0), np.float32(2997.0), np.float32(2998.0), np.float32(2999.0), np.float32(3000.0), np.float32(3001.0), np.float32(3002.0), np.float32(3003.0), np.float32(3004.0), np.float32(3005.0), np.float32(3006.0), np.float32(3007.0), np.float32(3008.0), np.float32(3009.0), np.float32(3010.0), np.float32(3011.0), np.float32(3012.0), np.float32(3013.0), np.float32(3014.0), np.float32(3015.0), np.float32(3016.0), np.float32(3017.0), np.float32(3018.0), np.float32(3019.0), np.float32(3020.0), np.float32(3021.0), np.float32(3022.0), np.float32(3023.0), np.float32(3024.0), np.float32(3025.0), np.float32(3026.0), np.float32(3027.0), np.float32(3028.0), np.float32(3029.0), np.float32(3030.0), np.float32(3031.0), np.float32(3032.0), np.float32(3033.0), np.float32(3034.0), np.float32(3035.0), np.float32(3036.0), np.float32(3037.0), np.float32(3038.0), np.float32(3039.0), np.float32(3040.0), np.float32(3041.0), np.float32(3042.0), np.float32(3043.0), np.float32(3044.0), np.float32(3045.0), np.float32(3046.0), np.float32(3047.0), np.float32(3048.0), np.float32(3049.0), np.float32(3050.0), np.float32(3051.0), np.float32(3052.0), np.float32(3053.0), np.float32(3054.0), np.float32(3055.0), np.float32(3056.0), np.float32(3057.0), np.float32(3058.0), np.float32(3059.0), np.float32(3060.0), np.float32(3061.0), np.float32(3062.0), np.float32(3063.0), np.float32(3064.0), np.float32(3065.0), np.float32(3066.0), np.float32(3067.0), np.float32(3068.0), np.float32(3069.0), np.float32(3070.0), np.float32(3071.0), np.float32(3072.0), np.float32(3073.0), np.float32(3074.0), np.float32(3075.0), np.float32(3076.0), np.float32(3077.0), np.float32(3078.0), np.float32(3079.0), np.float32(3080.0), np.float32(3081.0), np.float32(3082.0), np.float32(3083.0), np.float32(3084.0), np.float32(3085.0), np.float32(3086.0), np.float32(3087.0), np.float32(3088.0), np.float32(3089.0), np.float32(3090.0), np.float32(3091.0), np.float32(3092.0), np.float32(3093.0), np.float32(3123.0), np.float32(3163.0), np.float32(3177.5), np.float32(3185.0), np.float32(3190.5), np.float32(3196.0), np.float32(3200.5), np.float32(3204.0), np.float32(3211.5), np.float32(3218.5), np.float32(3221.0), np.float32(3228.5), np.float32(3243.0), np.float32(3254.5), np.float32(3320.0), np.float32(3382.5), np.float32(3453.625), np.float32(3724.75), np.float32(3944.5), np.float32(4006.4531), np.float32(4645.125)], min=2975.00, max=4645.12 -> x = 3810.06
#   Node 416311: INTERNAL, children_x=[np.float32(2972.0), np.float32(3810.0625)], min=2972.00, max=3810.06 -> x = 3391.03
#   Node 419258: INTERNAL, children_x=[np.float32(2967.0), np.float32(3391.0312)], min=2967.00, max=3391.03 -> x = 3179.02
#   Node 419561: INTERNAL, children_x=[np.float32(1943.0), np.float32(1944.0), np.float32(1945.0), np.float32(1946.0), np.float32(1947.0), np.float32(1948.0), np.float32(1949.0), np.float32(1950.0), np.float32(1951.0), np.float32(1952.0), np.float32(1953.0), np.float32(1954.0), np.float32(1955.0), np.float32(1956.0), np.float32(1957.0), np.float32(1958.0), np.float32(1959.0), np.float32(1960.0), np.float32(1961.0), np.float32(1962.0), np.float32(1963.0), np.float32(1964.0), np.float32(1965.0), np.float32(1966.0), np.float32(1967.0), np.float32(1968.0), np.float32(1969.0), np.float32(1970.0), np.float32(1971.0), np.float32(1972.0), np.float32(1973.0), np.float32(1974.0), np.float32(1975.0), np.float32(1976.0), np.float32(1977.0), np.float32(1978.0), np.float32(1979.0), np.float32(1980.0), np.float32(1981.0), np.float32(1982.0), np.float32(1983.0), np.float32(1984.0), np.float32(1985.0), np.float32(1986.0), np.float32(1987.0), np.float32(1988.0), np.float32(1989.0), np.float32(1990.0), np.float32(1991.0), np.float32(1992.0), np.float32(1993.0), np.float32(1994.0), np.float32(1995.0), np.float32(1996.0), np.float32(1997.0), np.float32(1998.0), np.float32(1999.0), np.float32(2000.0), np.float32(2001.0), np.float32(2002.0), np.float32(2003.0), np.float32(2004.0), np.float32(2005.0), np.float32(2006.0), np.float32(2007.0), np.float32(2008.0), np.float32(2009.0), np.float32(2010.0), np.float32(2011.0), np.float32(2012.0), np.float32(2013.0), np.float32(2014.0), np.float32(2015.0), np.float32(2016.0), np.float32(2017.0), np.float32(2018.0), np.float32(2019.0), np.float32(2020.0), np.float32(2021.0), np.float32(2022.0), np.float32(2023.0), np.float32(2024.0), np.float32(2025.0), np.float32(2026.0), np.float32(2027.0), np.float32(2028.0), np.float32(2029.0), np.float32(2030.0), np.float32(2031.0), np.float32(2032.0), np.float32(2033.0), np.float32(2034.0), np.float32(2035.0), np.float32(2036.0), np.float32(2037.0), np.float32(2038.0), np.float32(2039.0), np.float32(2040.0), np.float32(2041.0), np.float32(2042.0), np.float32(2043.0), np.float32(2044.0), np.float32(2045.0), np.float32(2046.0), np.float32(2047.0), np.float32(2048.0), np.float32(2049.0), np.float32(2050.0), np.float32(2051.0), np.float32(2052.0), np.float32(2053.0), np.float32(2054.0), np.float32(2055.0), np.float32(2056.0), np.float32(2057.0), np.float32(2058.0), np.float32(2059.0), np.float32(2060.0), np.float32(2061.0), np.float32(2062.0), np.float32(2063.0), np.float32(2064.0), np.float32(2065.0), np.float32(2066.0), np.float32(2067.0), np.float32(2068.0), np.float32(2069.0), np.float32(2070.0), np.float32(2071.0), np.float32(2072.0), np.float32(2073.0), np.float32(2074.0), np.float32(2075.0), np.float32(2076.0), np.float32(2077.0), np.float32(2078.0), np.float32(2079.0), np.float32(2080.0), np.float32(2081.0), np.float32(2082.0), np.float32(2083.0), np.float32(2084.0), np.float32(2085.0), np.float32(2086.0), np.float32(2087.0), np.float32(2088.0), np.float32(2089.0), np.float32(2090.0), np.float32(2091.0), np.float32(2092.0), np.float32(2093.0), np.float32(2094.0), np.float32(2095.0), np.float32(2096.0), np.float32(2097.0), np.float32(2098.0), np.float32(2099.0), np.float32(2100.0), np.float32(2101.0), np.float32(2102.0), np.float32(2103.0), np.float32(2104.0), np.float32(2105.0), np.float32(2106.0), np.float32(2107.0), np.float32(2108.0), np.float32(2109.0), np.float32(2110.0), np.float32(2111.0), np.float32(2112.0), np.float32(2113.0), np.float32(2114.0), np.float32(2115.0), np.float32(2116.0), np.float32(2117.0), np.float32(2118.0), np.float32(2119.0), np.float32(2120.0), np.float32(2121.0), np.float32(2122.0), np.float32(2123.0), np.float32(2124.0), np.float32(2125.0), np.float32(2126.0), np.float32(2127.0), np.float32(2128.0), np.float32(2129.0), np.float32(2130.0), np.float32(2131.0), np.float32(2132.0), np.float32(2133.0), np.float32(2134.0), np.float32(2135.0), np.float32(2136.0), np.float32(2137.0), np.float32(2138.0), np.float32(2139.0), np.float32(2140.0), np. ...
#   Node 419886: INTERNAL, children_x=[np.float32(1765.0), np.float32(1766.0), np.float32(1771.5), np.float32(1859.25), np.float32(2561.0078)], min=1765.00, max=2561.01 -> x = 2163.00
#   Node 420112: INTERNAL, children_x=[np.float32(1756.0), np.float32(1757.0), np.float32(1758.0), np.float32(1759.0), np.float32(1760.0), np.float32(1761.0), np.float32(1762.0), np.float32(1763.0), np.float32(1764.0), np.float32(2163.004)], min=1756.00, max=2163.00 -> x = 1959.50
#   Node 425022: INTERNAL, children_x=[np.float32(1708.0), np.float32(1709.0), np.float32(1710.0), np.float32(1711.0), np.float32(1712.0), np.float32(1713.0), np.float32(1714.0), np.float32(1715.0), np.float32(1716.0), np.float32(1717.0), np.float32(1718.0), np.float32(1719.0), np.float32(1720.0), np.float32(1721.0), np.float32(1722.0), np.float32(1723.0), np.float32(1724.0), np.float32(1725.0), np.float32(1726.0), np.float32(1727.0), np.float32(1728.0), np.float32(1729.0), np.float32(1730.0), np.float32(1731.0), np.float32(1732.0), np.float32(1733.0), np.float32(1734.0), np.float32(1735.5), np.float32(1744.75), np.float32(1959.502)], min=1708.00, max=1959.50 -> x = 1833.75
#   Node 426001: INTERNAL, children_x=[np.float32(1701.0), np.float32(1702.0), np.float32(1703.0), np.float32(1704.0), np.float32(1705.0), np.float32(1706.0), np.float32(1707.0), np.float32(1833.751)], min=1701.00, max=1833.75 -> x = 1767.38
#   Node 428524: INTERNAL, children_x=[np.float32(1694.0), np.float32(1695.0), np.float32(1696.0), np.float32(1697.0), np.float32(1698.0), np.float32(1699.0), np.float32(1700.0), np.float32(1767.3755)], min=1694.00, max=1767.38 -> x = 1730.69
#   Node 432940: INTERNAL, children_x=[np.float32(1684.0), np.float32(1685.0), np.float32(1686.0), np.float32(1687.0), np.float32(1688.0), np.float32(1689.0), np.float32(1690.0), np.float32(1691.0), np.float32(1692.0), np.float32(1693.0), np.float32(1730.6877)], min=1684.00, max=1730.69 -> x = 1707.34
#   Node 433994: INTERNAL, children_x=[np.float32(0.0), np.float32(1.0), np.float32(2.0), np.float32(3.0), np.float32(4.0), np.float32(5.0), np.float32(6.0), np.float32(7.0), np.float32(8.0), np.float32(9.0), np.float32(10.0), np.float32(11.0), np.float32(12.0), np.float32(13.0), np.float32(14.0), np.float32(15.0), np.float32(16.0), np.float32(17.0), np.float32(18.0), np.float32(19.0), np.float32(20.0), np.float32(21.0), np.float32(22.0), np.float32(23.0), np.float32(24.0), np.float32(25.0), np.float32(26.0), np.float32(27.0), np.float32(28.0), np.float32(29.0), np.float32(30.0), np.float32(31.0), np.float32(32.0), np.float32(33.0), np.float32(34.0), np.float32(35.0), np.float32(36.0), np.float32(37.0), np.float32(38.0), np.float32(39.0), np.float32(40.0), np.float32(41.0), np.float32(42.0), np.float32(43.0), np.float32(44.0), np.float32(45.0), np.float32(46.0), np.float32(47.0), np.float32(48.0), np.float32(49.0), np.float32(50.0), np.float32(51.0), np.float32(52.0), np.float32(53.0), np.float32(54.0), np.float32(55.0), np.float32(56.0), np.float32(57.0), np.float32(58.0), np.float32(59.0), np.float32(60.0), np.float32(61.0), np.float32(62.0), np.float32(63.0), np.float32(64.0), np.float32(65.0), np.float32(66.0), np.float32(67.0), np.float32(68.0), np.float32(69.0), np.float32(70.0), np.float32(71.0), np.float32(72.0), np.float32(73.0), np.float32(74.0), np.float32(75.0), np.float32(76.0), np.float32(77.0), np.float32(78.0), np.float32(79.0), np.float32(80.0), np.float32(81.0), np.float32(82.0), np.float32(83.0), np.float32(84.0), np.float32(85.0), np.float32(86.0), np.float32(87.0), np.float32(88.0), np.float32(89.0), np.float32(90.0), np.float32(91.0), np.float32(92.0), np.float32(93.0), np.float32(94.0), np.float32(95.0), np.float32(96.0), np.float32(97.0), np.float32(98.0), np.float32(99.0), np.float32(100.0), np.float32(101.0), np.float32(102.0), np.float32(103.0), np.float32(104.0), np.float32(105.0), np.float32(106.0), np.float32(107.0), np.float32(108.0), np.float32(109.0), np.float32(110.0), np.float32(111.0), np.float32(112.0), np.float32(113.0), np.float32(114.0), np.float32(115.0), np.float32(116.0), np.float32(117.0), np.float32(118.0), np.float32(119.0), np.float32(120.0), np.float32(121.0), np.float32(122.0), np.float32(123.0), np.float32(124.0), np.float32(125.0), np.float32(126.0), np.float32(127.0), np.float32(128.0), np.float32(129.0), np.float32(130.0), np.float32(131.0), np.float32(132.0), np.float32(133.0), np.float32(134.0), np.float32(135.0), np.float32(136.0), np.float32(137.0), np.float32(138.0), np.float32(139.0), np.float32(140.0), np.float32(141.0), np.float32(142.0), np.float32(143.0), np.float32(144.0), np.float32(145.0), np.float32(146.0), np.float32(147.0), np.float32(148.0), np.float32(149.0), np.float32(150.0), np.float32(151.0), np.float32(152.0), np.float32(153.0), np.float32(154.0), np.float32(155.0), np.float32(156.0), np.float32(157.0), np.float32(158.0), np.float32(159.0), np.float32(160.0), np.float32(161.0), np.float32(162.0), np.float32(163.0), np.float32(164.0), np.float32(165.0), np.float32(166.0), np.float32(167.0), np.float32(168.0), np.float32(169.0), np.float32(170.0), np.float32(171.0), np.float32(172.0), np.float32(173.0), np.float32(174.0), np.float32(175.0), np.float32(176.0), np.float32(177.0), np.float32(178.0), np.float32(179.0), np.float32(180.0), np.float32(181.0), np.float32(182.0), np.float32(183.0), np.float32(184.0), np.float32(185.0), np.float32(186.0), np.float32(187.0), np.float32(188.0), np.float32(189.0), np.float32(190.0), np.float32(191.0), np.float32(192.0), np.float32(193.0), np.float32(194.0), np.float32(195.0), np.float32(196.0), np.float32(197.0), np.float32(198.0), np.float32(199.0), np.float32(200.0), np.float32(201.0), np.float32(202.0), np.float32(203.0), np.float32(210.5), np.float32(219.0), np.float32(259.75), np.float32(302.0), np.float32(312.0), np.float32(330.5), np.float32(347.0), np.float32(379.25), np.float32(411.5), np.float32(445.25), np.f ...
#
# Tip count: 5008

# %%
# Numba-optimized version (production code)
@njit(cache=True)
def _compute_x_postorder(children_indptr, children_data, roots, num_nodes):
    """
    Numba-compiled post-order traversal for computing x (layout) coordinates.
    
    Tips get sequential x values (0, 1, 2, ...).
    Internal nodes get (min + max) / 2 of children's x values (matches jstree.js).
    Children are pushed in reverse order so they're processed left-to-right (matching Newick).
    
    Args:
        children_indptr: CSR indptr array
        children_data: CSR data array (flattened children)
        roots: Array of root node IDs
        num_nodes: Total number of nodes
    
    Returns:
        (x, tip_counter): x coordinates array and number of tips
    """
    x = np.full(num_nodes, -1.0, dtype=np.float32)
    tip_counter = 0
    
    # Pre-allocated stack arrays (avoid Python list overhead)
    stack_nodes = np.empty(num_nodes, dtype=np.int32)
    stack_visited = np.empty(num_nodes, dtype=np.uint8)  # 0=False, 1=True
    
    for i in range(len(roots)):
        root = roots[i]
        stack_ptr = 0
        
        # Push root onto stack
        stack_nodes[stack_ptr] = root
        stack_visited[stack_ptr] = 0
        stack_ptr += 1
        
        while stack_ptr > 0:
            # Pop from stack
            stack_ptr -= 1
            node = stack_nodes[stack_ptr]
            visited = stack_visited[stack_ptr]
            
            # CSR lookup for children
            start = children_indptr[node]
            end = children_indptr[node + 1]
            num_children = end - start
            
            if visited == 0 and num_children > 0:
                # First visit: push node back as visited, then push children
                stack_nodes[stack_ptr] = node
                stack_visited[stack_ptr] = 1
                stack_ptr += 1
                
                # Push all children in REVERSE order (so first child is processed first)
                # This matches Newick traversal order
                for j in range(end - 1, start - 1, -1):
                    stack_nodes[stack_ptr] = children_data[j]
                    stack_visited[stack_ptr] = 0
                    stack_ptr += 1
            else:
                # Post-order processing
                if num_children == 0:
                    # Tip: sequential x value
                    x[node] = tip_counter
                    tip_counter += 1
                else:
                    # Internal: (min + max) / 2 of children (matches jstree.js)
                    min_x = x[children_data[start]]
                    max_x = x[children_data[start]]
                    for j in range(start + 1, end):
                        child_x = x[children_data[j]]
                        if child_x < min_x:
                            min_x = child_x
                        if child_x > max_x:
                            max_x = child_x
                    x[node] = (min_x + max_x) / 2.0
    
    return x, tip_counter

# Run Numba version
x_numba, tip_count_numba = _compute_x_postorder(
    children_indptr, children_data, roots.astype(np.int32), num_nodes
)

# Verify both versions match
print("Comparing Python vs Numba implementations:")
print(f"  Tip counts: Python={tip_count}, Numba={tip_count_numba}")
matches = np.allclose(x_python[in_tree], x_numba[in_tree], atol=1e-6)
print(f"  X values match: {matches}")
# Out:
# Comparing Python vs Numba implementations:
#   Tip counts: Python=5008, Numba=5008
#   X values match: True

# %%
# Use the Numba result and normalize to [0, 1]
x = x_numba.copy()
if tip_count_numba > 1:
    x[in_tree] /= (tip_count_numba - 1)

print("Final X coordinates (normalized to [0, 1]):")
print(f"{'node_id':>8} {'x':>8} {'type':>10}")
print("-" * 28)

# Show some nodes
for node_id in np.where(in_tree)[0][:10]:
    node_type = "TIP" if is_tip(node_id) else "INTERNAL"
    if parent[node_id] == -1:
        node_type = "ROOT"
    print(f"{node_id:>8} {x[node_id]:>8.4f} {node_type:>10}")
# Out:
# Final X coordinates (normalized to [0, 1]):
#  node_id        x       type
# ----------------------------
#        0   0.4941        TIP
#        1   0.9055        TIP
#        2   0.6487        TIP
#        3   0.9057        TIP
#        4   0.0441        TIP
#        5   0.4438        TIP
#        6   0.3779        TIP
#        7   0.3881        TIP
#        8   0.1266        TIP
#        9   0.7525        TIP

# %% [markdown]
# ## Cell 9: TreeGraph Dataclass
#
# We package all computed data into a dataclass for clean organization:

# %%
@dataclass
class TreeGraph:
    """
    Graph representation using numpy arrays with CSR format for children.
    
    Attributes:
        parent: int32 array where parent[node_id] = parent_id (-1 for root)
        time: float32 array of raw node times
        children_indptr: int32 CSR row pointers (length = num_nodes + 1)
        children_data: int32 flattened children array
        x: float32 layout position [0,1] (tips spread, internal=(min+max)/2 of children)
        y: float32 normalized time [0,1] (max_time=0, min_time=1)
        in_tree: bool array indicating which nodes are in this tree
    """
    parent: np.ndarray
    time: np.ndarray
    children_indptr: np.ndarray
    children_data: np.ndarray
    x: np.ndarray
    y: np.ndarray
    in_tree: np.ndarray
    
    def children(self, node_id: int) -> np.ndarray:
        """Get children of a node as numpy array slice (zero-copy)."""
        return self.children_data[self.children_indptr[node_id]:self.children_indptr[node_id + 1]]
    
    def is_tip(self, node_id: int) -> bool:
        """Check if a node is a tip (no children)."""
        return self.children_indptr[node_id + 1] == self.children_indptr[node_id]

# Create TreeGraph from our computed arrays
graph = TreeGraph(
    parent=parent,
    time=node_times.astype(np.float32),
    children_indptr=children_indptr,
    children_data=children_data,
    x=x,
    y=y,
    in_tree=in_tree
)

print(f"TreeGraph created!")
print(f"  Nodes in tree: {np.sum(graph.in_tree)}")
print(f"  X range: [{graph.x[graph.in_tree].min():.4f}, {graph.x[graph.in_tree].max():.4f}]")
print(f"  Y range: [{graph.y[graph.in_tree].min():.4f}, {graph.y[graph.in_tree].max():.4f}]")
# Out:
# TreeGraph created!
#   Nodes in tree: 5337
#   X range: [0.0000, 1.0000]
#   Y range: [0.0000, 1.0000]

# %% [markdown]
# ## Cell 10: Complete `construct_tree()` Function
#
# Here's the full function that combines all steps. This is the production code used by the Lorax backend:

# %%
def construct_tree(
    ts,
    edges,
    nodes,
    breakpoints,
    index: int,
    min_time: Optional[float] = None,
    max_time: Optional[float] = None
) -> TreeGraph:
    """
    Construct tree with x,y coordinates using Numba-optimized post-order traversal.
    
    Args:
        ts: tskit TreeSequence object
        edges: ts.tables.edges (pre-extracted for reuse)
        nodes: ts.tables.nodes (pre-extracted for reuse)
        breakpoints: list/array of breakpoints (pre-extracted for reuse)
        index: Tree index
        min_time: Optional global min time (default: ts.min_time)
        max_time: Optional global max time (default: ts.max_time)
    
    Returns:
        TreeGraph with CSR children and x,y coordinates in [0,1].
    """
    if index < 0 or index >= ts.num_trees:
        raise ValueError(f"Tree index {index} out of range [0, {ts.num_trees - 1}]")
    
    interval_left = breakpoints[index]
    num_nodes = len(nodes.time)
    node_times = nodes.time
    
    # Use provided min/max or compute from ts
    if min_time is None:
        min_time = ts.min_time
    if max_time is None:
        max_time = ts.max_time
    
    # === Edge filtering & parent array ===
    active_mask = (edges.left <= interval_left) & (edges.right > interval_left)
    active_parents = edges.parent[active_mask]
    active_children = edges.child[active_mask]
    
    parent = np.full(num_nodes, -1, dtype=np.int32)
    parent[active_children] = active_parents
    
    # === CSR children structure ===
    child_counts = np.bincount(active_parents, minlength=num_nodes).astype(np.int32)
    children_indptr = np.zeros(num_nodes + 1, dtype=np.int32)
    children_indptr[1:] = np.cumsum(child_counts)
    sort_idx = np.argsort(active_parents, kind='stable')
    children_data = active_children[sort_idx].astype(np.int32)
    
    # === Track which nodes are in this tree ===
    in_tree = np.zeros(num_nodes, dtype=np.bool_)
    in_tree[active_children] = True
    in_tree[active_parents] = True
    
    # === Y coordinate: normalized time (vectorized) ===
    time_range = max_time - min_time if max_time > min_time else 1.0
    y = ((max_time - node_times) / time_range).astype(np.float32)
    
    # === X coordinate: Numba-optimized post-order traversal ===
    roots = np.where(in_tree & (parent == -1))[0].astype(np.int32)
    x, tip_counter = _compute_x_postorder(children_indptr, children_data, roots, num_nodes)
    
    # Normalize x to [0, 1]
    if tip_counter > 1:
        x[in_tree] /= (tip_counter - 1)
    
    return TreeGraph(
        parent=parent,
        time=node_times.astype(np.float32),
        children_indptr=children_indptr,
        children_data=children_data,
        x=x,
        y=y,
        in_tree=in_tree
    )

# %% [markdown]
# ## Cell 11: Run the Algorithm

# %%
# Choose which tree to visualize
tree_idx = 0

# Pre-extract tables for efficiency
edges = ts.tables.edges
nodes = ts.tables.nodes
breakpoints = list(ts.breakpoints())

# Construct the tree graph
graph = construct_tree(ts, edges, nodes, breakpoints, tree_idx)

print(f"Tree {tree_idx} constructed:")
print(f"  Nodes in tree: {np.sum(graph.in_tree)}")
print(f"  Tips: {sum(1 for n in np.where(graph.in_tree)[0] if graph.is_tip(n))}")
print(f"  Roots: {list(np.where(graph.in_tree & (graph.parent == -1))[0])}")
print(f"")
print(f"  X range: [{graph.x[graph.in_tree].min():.4f}, {graph.x[graph.in_tree].max():.4f}]")
print(f"  Y range: [{graph.y[graph.in_tree].min():.4f}, {graph.y[graph.in_tree].max():.4f}]")
# Out:
# Tree 0 constructed:
#   Nodes in tree: 5337
#   Tips: 5008
#   Roots: [np.int64(433994)]
#
#   X range: [0.0000, 1.0000]
#   Y range: [0.0000, 1.0000]

# %% [markdown]
# ## Cell 12: Visualize the Result
#
# Let's plot the tree using matplotlib to verify the coordinates make sense:

# %%
# Get nodes in tree
indices = np.where(graph.in_tree)[0]

# Prepare colors: tips = green, internal = blue, roots = red
colors = []
for i in indices:
    if graph.parent[i] == -1:
        colors.append('red')  # Root
    elif graph.is_tip(i):
        colors.append('green')  # Tip
    else:
        colors.append('blue')  # Internal

# Create figure
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

# Draw edges (parent-child lines)
for node in indices:
    if graph.parent[node] != -1:
        p = graph.parent[node]
        # Draw elbow connector: vertical then horizontal
        ax.plot([graph.y[node], graph.y[p]], [graph.x[node], graph.x[node]], 
                'k-', alpha=0.4, linewidth=0.8)
        ax.plot([graph.y[p], graph.y[p]], [graph.x[node], graph.x[p]], 
                'k-', alpha=0.4, linewidth=0.8)

# Draw nodes
ax.scatter(graph.y[indices], graph.x[indices], c=colors, s=30, zorder=5)

# Labels
ax.set_xlabel('Y (normalized time: 0=root, 1=tips)')
ax.set_ylabel('X (layout position)')
ax.set_title(f'Tree {tree_idx} Visualization\n({np.sum(graph.in_tree)} nodes)')

# Legend
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='red', label='Root'),
    Patch(facecolor='blue', label='Internal'),
    Patch(facecolor='green', label='Tip')
]
ax.legend(handles=legend_elements, loc='upper right')

ax.set_xlim(-0.05, 1.05)
ax.set_ylim(-0.05, 1.05)
ax.set_aspect('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cell 13: PyArrow Serialization
#
# The frontend receives tree data via PyArrow IPC (Inter-Process Communication) format. This binary format is:
# - **Efficient**: Zero-copy reads in JavaScript via Arrow.js
# - **Compact**: Binary representation is smaller than JSON
# - **Typed**: Schema guarantees correct data types
#
# Note: We swap x and y coordinates for the backend convention:
# - Backend x = time (our y)
# - Backend y = layout (our x)

# %%
def to_pyarrow(graph: TreeGraph, tree_idx: int = 0) -> bytes:
    """
    Serialize TreeGraph to PyArrow IPC format for frontend rendering.
    
    Note: Coordinates are swapped to match backend convention:
    - Backend x = self.y (time)
    - Backend y = self.x (layout)
    
    Args:
        graph: TreeGraph instance
        tree_idx: Tree index to include in output
    
    Returns:
        bytes: PyArrow IPC binary data
    """
    # Get nodes that are in this tree
    indices = np.where(graph.in_tree)[0].astype(np.int32)
    n = len(indices)
    
    if n == 0:
        table = pa.table({
            'node_id': pa.array([], type=pa.int32()),
            'parent_id': pa.array([], type=pa.int32()),
            'is_tip': pa.array([], type=pa.bool_()),
            'tree_idx': pa.array([], type=pa.int32()),
            'x': pa.array([], type=pa.float32()),
            'y': pa.array([], type=pa.float32()),
        })
    else:
        # Derive is_tip from CSR
        child_counts = np.diff(graph.children_indptr)
        is_tip = child_counts[indices] == 0
        
        # Build PyArrow table (swap x<->y for backend convention)
        table = pa.table({
            'node_id': pa.array(indices, type=pa.int32()),
            'parent_id': pa.array(graph.parent[indices], type=pa.int32()),
            'is_tip': pa.array(is_tip, type=pa.bool_()),
            'tree_idx': pa.array(np.full(n, tree_idx, dtype=np.int32), type=pa.int32()),
            'x': pa.array(graph.y[indices], type=pa.float32()),  # SWAP: time -> x
            'y': pa.array(graph.x[indices], type=pa.float32()),  # SWAP: layout -> y
        })
    
    # Serialize to IPC format
    sink = pa.BufferOutputStream()
    writer = pa.ipc.new_stream(sink, table.schema)
    writer.write_table(table)
    writer.close()
    
    return sink.getvalue().to_pybytes()

# Serialize our tree
buffer = to_pyarrow(graph, tree_idx)

print(f"PyArrow Serialization:")
print(f"  Buffer size: {len(buffer):,} bytes")
print(f"  Nodes: {np.sum(graph.in_tree)}")
print(f"  Bytes per node: {len(buffer) / np.sum(graph.in_tree):.1f}")
print(f"")

# Verify by reading back
reader = pa.ipc.open_stream(buffer)
table = reader.read_all()
print(f"Schema:")
print(table.schema)
print(f"")
print(f"First 5 rows:")
print(table.slice(0, 5).to_pandas())
# Out:
# PyArrow Serialization:
#   Buffer size: 108,208 bytes
#   Nodes: 5337
#   Bytes per node: 20.3
#
# Schema:
# node_id: int32
# parent_id: int32
# is_tip: bool
# tree_idx: int32
# x: float
# y: float
#
# First 5 rows:
#    node_id  parent_id  is_tip  tree_idx    x         y
# 0        0     141729    True         0  1.0  0.494108
# 1        1     388119    True         0  1.0  0.905532
# 2        2     345410    True         0  1.0  0.648692
# 3        3     388119    True         0  1.0  0.905732
# 4        4      95588    True         0  1.0  0.044138

# %% [markdown]
# ## Cell 14: Compare with tskit's Built-in Tree
#
# Let's verify our implementation matches tskit's internal representation:

# %%
# Get tskit's tree object
tskit_tree = ts.at_index(tree_idx)

print(f"=== Comparison: Our TreeGraph vs tskit Tree ===")
print(f"")
print(f"Basic stats:")
print(f"  Our nodes in tree: {np.sum(graph.in_tree)}")
print(f"  tskit num_nodes: {tskit_tree.num_nodes}")
print(f"  tskit num_samples: {tskit_tree.num_samples}")
print(f"")

# Get tskit's roots
tskit_roots = list(tskit_tree.roots)
our_roots = list(np.where(graph.in_tree & (graph.parent == -1))[0])
print(f"Roots:")
print(f"  Our roots: {our_roots}")
print(f"  tskit roots: {tskit_roots}")
print(f"  Match: {set(our_roots) == set(tskit_roots)}")
print(f"")

# Compare parent arrays for in-tree nodes
print(f"Parent array comparison:")
mismatches = 0
for node in np.where(graph.in_tree)[0]:
    tskit_parent = tskit_tree.parent(node)
    our_parent = graph.parent[node]
    if tskit_parent != our_parent:
        print(f"  MISMATCH at node {node}: ours={our_parent}, tskit={tskit_parent}")
        mismatches += 1

if mismatches == 0:
    print(f"  All parent values match!")
print(f"")

# Compare children for a few nodes
print(f"Children comparison (first 5 internal nodes):")
internal_nodes = [n for n in np.where(graph.in_tree)[0] if not graph.is_tip(n)][:5]
for node in internal_nodes:
    our_children = set(graph.children(node))
    tskit_children = set(tskit_tree.children(node))
    match = "OK" if our_children == tskit_children else "MISMATCH"
    print(f"  Node {node}: ours={sorted(our_children)}, tskit={sorted(tskit_children)} [{match}]")
# Out:
# === Comparison: Our TreeGraph vs tskit Tree ===
#
# Basic stats:
#   Our nodes in tree: 160
#   tskit num_nodes: 176
#   tskit num_samples: <bound method Tree.num_samples of <tskit.trees.Tree object at 0x7f080e56c410>>
#
# Roots:
#   Our roots: [np.int64(0), np.int64(2)]
#   tskit roots: [0, 2]
#   Match: True
#
# Parent array comparison:
#   All parent values match!
#
# Children comparison (first 5 internal nodes):
#   Node 0: ours=[np.int32(135)], tskit=[135] [OK]
#   Node 2: ours=[np.int32(4)], tskit=[4] [OK]
#   Node 4: ours=[np.int32(7), np.int32(20)], tskit=[7, 20] [OK]
#   Node 7: ours=[np.int32(9), np.int32(18)], tskit=[9, 18] [OK]
#   Node 9: ours=[np.int32(11), np.int32(13)], tskit=[11, 13] [OK]
# /home/pratik/anaconda3/envs/lorax/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3639: FutureWarning: This property is a deprecated alias for Tree.tree_sequence.num_nodes and will be removed in the future. To obtain the number of nodes in the topology of the current tree (i.e. reachable from the roots) use len(tree.preorder()).
#   if await self.run_code(code, result, async_=asy):

# %% [markdown]
# ## Summary
#
# This notebook demonstrated the complete pipeline for converting tskit tree sequences into renderable graph structures:
#
# ### Key Algorithm Steps
#
# 1. **Edge Filtering**: `active_mask = (edges.left <= pos) & (edges.right > pos)`
# 2. **Parent Array**: `parent[child] = parent_node` for O(1) lookups
# 3. **CSR Children**: Compressed Sparse Row format for efficient graph traversal
# 4. **Y Coordinate**: Normalized time `(max_time - time) / range`
# 5. **X Coordinate**: Post-order traversal with tips getting sequential values, internal nodes at `(min + max) / 2`
# 6. **Serialization**: PyArrow IPC for efficient network transfer
#
# ### Internal Node Positioning
#
# Internal nodes are positioned at the midpoint of their children's x-range: `(min_child_x + max_child_x) / 2`. This matches the jstree.js algorithm used by Taxonium and produces identical layouts to Newick-parsed trees.
#
# ### Performance Considerations
#
# - **Numba JIT**: The post-order traversal is compiled for ~100x speedup
# - **Vectorized operations**: NumPy broadcasting avoids Python loops
# - **CSR format**: O(1) children lookup without Python lists
# - **Pre-extracted tables**: Avoids repeated table access overhead
#
# ### Coordinate Convention
#
# The backend swaps x and y for the frontend:
# - **x (time)**: Root at 0, tips at 1 (horizontal axis)
# - **y (layout)**: Tips evenly distributed (vertical axis)
